# %%
# %%writefile regulatory_architecture_Mphage_fine.ini
#
# [x-axis]
# where = top
#
# [H1 Primed CTCF loops]
# file = /input_dir/corona_analysis/tracks/primed_.7_origami_intra.arcs
# title = Cohesin Chia-PET
# color = #00a110
# links_type = arcs
# ylim = 3000000
# line_style = solid
# line_width = 1.5
# height = 5
#
# #[CTCF NN variants]
# #file =
# #title = Variants CTCF perturbing
# #height = 1
# #color = #e90ef4
# #max_labels = 0
# #labels = false
# #file_type = bed
#
# [ENCFF117BRM_CTCF_CD14_mono]
# file = /input_dir/corona_analysis/tracks/ENCFF114WQR_cd14_monocyte_hg19_CTCF.bw
# title = CTCF chip-seq CD14 Mono
# height = 2
# color = #42f44e
# orientation = inverted
# min_value = 2
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [Macrophage Methylation]
# file=/input_dir/corona_analysis/tracks/S0022I51_macrophage_CPG_meth_hg19.bw
# title = Macrophage Methylation
# height = .5
# color = #21ffff
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [Macrophage activ Methylation]
# file=/input_dir/corona_analysis/tracks/S00BS451_activ_macrophage_CPG_meth_hg19.bw
# title = Macrophage activated methylation
# height = .5
# color = #21ffff
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [Macrophage H3k4me3]
# file = /input_dir/corona_analysis/tracks/S0022IH1_macrophage_h3k4me3_hg19.bw
# title = H3k4Me3 fc Chip-seq
# height = 2
# color = #ffb42b
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [Macrophage H3k27Ac]
# file = /input_dir/corona_analysis/tracks/S0022IH1_macrophage_h3k27Ac_hg19.bw
# title = H3k27Ac fc Chip-seq
# height = 2
# color = #42f4f4
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [Macrophage H3k9me3]
# file = /input_dir/corona_analysis/tracks/S0022IH1_macrophage_h3k9me3_hg19.bw
# title = H3k9Me3 fc Chip-seq
# height = 2
# color = #a22eea
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [CD14_mono]
# file = /input_dir/corona_analysis/tracks/E124_15_coreMarks_dense.bed.gz
# fontsize = 8
# height = 1
# title = CD14 Monocyte Chromatin State
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# [DNAse Peaks Macrophage]
# file = /input_dir/corona_analysis/tracks/S0022I44_macrophage_DNAse_hg19.bed
# title = DNAse Peaks
# file_type = bed
# height = 1
# line_width = 1
# labels = false
# show_labels = false
# color = #1d6ae5
# display = collapsed
# fontsize = 10
#
# [Macrophage Accessibility]
# #file = /input_dir/corona_analysis/tracks/S0022I44_macrophage_DNAse_hg19.bw
# file = /input_dir/corona_analysis/tracks/Mono_2_scATAC_hg19.bw
# title = Macrophage (mono 2) scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [CoVid-19_susceptibility]
# file = /input_dir/corona_analysis/tracks/covid_hg19_1e6_susceptibility.bed
# height = 1
# title = CoVid-19 susceptibility 1e-6
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [Ellinghaus CoVid GWAS]
# file = /input_dir/corona_analysis/tracks/Ellinghaus_covid_gwas_hg19.bed
# height = 1
# title = Ellinghaus CoVid GWAS
# color = #e90ef4
# max_labels = 0
# file_type = bed
#
# #[ClinVar kidney phenotype]
# #file = /input_dir/datavol/epigenetics_tracks/clinvar_kidney_variants_hg19.bed
# #height = 1
# #title = ClinVar w/ kidney phenotype
# #color = #e90ef4
# #max_labels = 0
# #file_type = bed
# #fontsize = 10
#
# [LINE elements]
# file = /input_dir/corona_analysis/annotations/hsflnil1_hg19_sorted.bed
# height = 1
# title = LINE retroelements
# fontsize = 10
# file_type = bed
#
# [Gencode genes]
# file = /input_dir/corona_analysis/annotations/gencode_v37.sorted.bed
# height = 4
# title = Gencode Genes
# fontsize = 8
# file_type = bed
# display = stacked
# labels_in_margin = false
# style = UCSC
# gene_rows = 10
# max_labels = 5000000
#
# [Mphage_rnaseq_plus]
# file = /input_dir/corona_analysis/tracks/S0022I12_Mphage_rnaseq_plus_hg19.bw
# title = RNA Mphage +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [Mphage_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/S0022I12_Mphage_rnaseq_minus_hg19.bw
# title = RNA Mphage -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [Mphage_activ_rnaseq_plus]
# file = /input_dir/corona_analysis/tracks/S0022I12_Mphage_activ_rnaseq_plus_hg19.bw
# title = RNA Inflammatory Mphage +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [Mphage_activ_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/S0022I12_Mphage_activ_rnaseq_minus_hg19.bw
# title = RNA Inflammatory Mphage -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# orientation = inverted
# summary_method = mean
# show_data_range = true
# file_type = bigwig

# %%
# %%writefile regulatory_architecture_Mphage_broad.ini
#
# [x-axis]
# where = top
#
# [PMA THP1 cell]
# file=/input_dir/corona_analysis/tracks/Macrophage_HiC_hg19_50000.cool
# title = PMA THP1 Hi-C
# colormap = coolwarm
# min_value = 2.6
# max_value = 7.8
# depth = 3000000
# transform = log
# show_masked_bins = False
# file_type = hic_matrix
# height = 10
#
# #[TAD Calls]
# #file = /input_dir/datavol/epigenetics_tracks/HEK293T_100kbTADs_domains.bed
# #file_type = domains
# #overlay_previous = share-y
# #fontsize = 8
# #line_width = 3
# #border_color = black
# #color = none
#
# [ENCFF117BRM_CTCF_CD14_mono]
# file = /input_dir/corona_analysis/tracks/ENCFF114WQR_cd14_monocyte_hg19_CTCF.bw
# title = CTCF chip-seq CD14 Mono
# height = 3
# color = #42f44e
# #overlay previous = yes
# orientation = inverted
# min_value = 2
# max_value = 10
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = True
# file_type = bigwig
#
# [H1 Primed CTCF loops]
# file = /input_dir/corona_analysis/tracks/primed_.7_origami_intra.arcs
# title = Cohesin Chia-PET
# color = #00a110
# links_type = arcs
# line_style = solid
# orientation=inverted
# line_width = 1.5
# height = 5
#
# [Macrophage DNAse]
# file = /input_dir/corona_analysis/tracks/S0022I44_macrophage_DNAse_hg19.bw
# title = DNase sensitivity
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [CD14_mono]
# file = /input_dir/corona_analysis/tracks/E124_15_coreMarks_dense.bed.gz
# fontsize = 8
# height = 1
# title = CD14 Monocyte Chromatin State
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# [CoVid-19_susceptibility]
# file = /input_dir/corona_analysis/tracks/covid_hg19_1e6_susceptibility.bed
# height = 1
# title = CoVid-19 susceptibility 1e-6
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [Ellinghaus CoVid GWAS]
# file = /input_dir/corona_analysis/tracks/Ellinghaus_covid_gwas_hg19.bed
# height = 1
# title = Ellinghaus CoVid GWAS
# color = #e90ef4
# max_labels = 0
# file_type = bed
#
# [LINE elements]
# file = /input_dir/corona_analysis/annotations/hsflnil1_hg19_sorted.bed
# height = 1
# title = LINE retroelements
# fontsize = 10
# file_type = bed
#
# [Gencode genes]
# file = /input_dir/corona_analysis/annotations/gencode_v37.sorted.bed
# height = 4
# title = Gencode Genes
# fontsize = 8
# file_type = bed
# display = stacked
# labels_in_margin = false
# style = UCSC
# gene_rows = 10
# max_labels = 5000000
#
# [Mphage_activ_rnaseq_plus]
# file = /input_dir/corona_analysis/tracks/S0022I12_Mphage_activ_rnaseq_plus_hg19.bw
# title = RNA Inflammatory Mphage +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [Mphage_activ_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/S0022I12_Mphage_activ_rnaseq_minus_hg19.bw
# title = RNA Inflammatory Mphage -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# orientation = inverted
# summary_method = mean
# show_data_range = true
# file_type = bigwig

# %% [markdown]
# # IL6

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_Mphage_fine.ini \
#     --region chr7:22764943-22768157 \
#     --outFileName /input_dir/corona_analysis/out_viz/IL6_TSS_hg19_macrophage.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_Mphage_fine.ini \
#     --region chr7:22764162-22783446 \
#     --outFileName /input_dir/corona_analysis/out_viz/IL6_gene_hg19_macrophage.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_Mphage_broad.ini \
#     --region chr7:22531171-23599614 \
#     --outFileName /input_dir/corona_analysis/out_viz/IL6_TAD_hg19_broad_macrophage.pdf

# %% [markdown]
# # CXCL16

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_Mphage_fine.ini \
#     --region chr17:4641617-4643428 \
#     --outFileName /input_dir/corona_analysis/out_viz/CXCL16_TSS_hg19_mphage.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_Mphage_fine.ini \
#     --region chr17:4636153-4644459 \
#     --outFileName /input_dir/corona_analysis/out_viz/CXCL16_gene_hg19_mphage.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_Mphage_broad.ini \
#     --region chr17:4306454-5011972 \
#     --outFileName /input_dir/corona_analysis/out_viz/CXCL16_TAD_hg19_mphage.pdf
