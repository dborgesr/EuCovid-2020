# %%
# %%writefile regulatory_architecture_tcell_fine.ini
#
# [x-axis]
# where = top
#
# [H1 Primed CTCF loops]
# file = /input_dir/corona_analysis/tracks/primed_.7_origami_intra_hg38.arcs
# title = Cohesin Chia-PET
# color = #00a110
# links_type = arcs
# ylim = 300000
# line_style = solid
# line_width = 1.5
# height = 5
#
# #[CTCF NN variants]
# #file =
# #title = Variants CTCF perturbing
# #height = 1
# #color = #e90ef4
# #max_labels = 0
# #labels = false
# #file_type = bed
#
# [ENCFF518JVS_cd8_tcell_imputed]
# file = /input_dir/corona_analysis/tracks/ENCFF518JVS_cd8_tcell_imputed_hg38.bw
# title = CTCF chip-seq CD8 Tcell imputed
# height = 3
# color = #42f44e
# #overlay previous = yes
# orientation = inverted
# min_value = 2
# max_value = 10
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = True
# file_type = bigwig
#
# [CD8_effmemT_CPG_meth]
# file = /input_dir/corona_analysis/tracks/S002ND51_CD8_effmemT_CPG_meth_hg38.bw
# title = CD8+ eff memory T-cell C-meth
# height = .5
# color = #21ffff
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [T-cell CD8 h3k4me3]
# file = /input_dir/corona_analysis/tracks/C0054X_cd8_tcell_h3k4me3_hg38.bw
# title = CD8 T-cell H3k4Me3 fc Chip-seq
# height = 2
# color = #ffb42b
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-cell CD8 H3k27Ac]
# file = /input_dir/corona_analysis/tracks/C0054X_cd8_tcell_h3k27Ac_hg38.bw
# title = CD8 T-cell H3k27Ac fc Chip-seq
# height = 2
# color = #42f4f4
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-cell CD8 H3k9Me3]
# file = /input_dir/corona_analysis/tracks/C0054X_cd8_tcell_h3k9me3_hg38.bw
# title = CD8 T-cell H3k9Me3 fc Chip-seq
# height = 2
# color = #a22eea
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell 1 cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_N_T1_scATAC_hg38.bw
# title = [T-Cell 1 cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell 2 cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_N_T2_scATAC_hg38.bw
# title = [T-Cell 2 cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell 3 cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_N_T3_scATAC_hg38.bw
# title = T-Cell 3 cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell EM cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_EM_T_scATAC_hg38.bw
# title = T-Cell EM cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell CM cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_CM_T_scATAC_hg38.bw
# title = T-Cell CM cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [CD8_MEMORY_PRIMARY_CELLS]
# #file = /input_dir/corona_analysis/tracks/CD8_MEMORY_PRIMARY_CELLS_hg38.bed.gz
# file = /input_dir/corona_analysis/tracks/E048_15_coreMarks_dense_hg38.bed.gz
# fontsize = 8
# height = 1
# title = CD8 Tcell memory cells
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# [CD8_NAIVE_PRIMARY_CELLS]
# #file = /input_dir/corona_analysis/tracks/CD8_NAIVE_PRIMARY_CELLS_hg38.bed.gz
# file = /input_dir/corona_analysis/tracks/E047_15_coreMarks_dense_hg38.bed.gz
# fontsize = 8
# height = 1
# title = CD8 Tcell naive cells
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# [spacer]
# height = 1
#
# [COPD GWAS]
# file = /input_dir/corona_analysis/tracks/COPD_GWAS_hg38.bed
# height = 1
# title = COPD GWAS
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [IPF GWAS]
# file = /input_dir/corona_analysis/tracks/ipf_gwas_hg38_allen_5e-8.bed
# height = 1
# title = IPF GWAS
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [CoVid-19_susceptibility]
# file = /input_dir/corona_analysis/tracks/covid_hg38_1e6_susceptibility.bed
# height = 1
# title = CoVid-19 susceptibility 1e-6
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [Ellinghaus CoVid GWAS]
# file = /input_dir/corona_analysis/tracks/Ellinghaus_covid_gwas_hg38.bed
# height = 1
# title = Ellinghaus CoVid GWAS
# color = #e90ef4
# max_labels = 0
# file_type = bed
#
# #[ClinVar kidney phenotype]
# #file = /input_dir/datavol/epigenetics_tracks/clinvar_kidney_variants_hg38.bed
# #height = 1
# #title = ClinVar w/ immune phenotype
# #color = #e90ef4
# #max_labels = 0
# #file_type = bed
# #fontsize = 10
#
# [LINE elements]
# file = /input_dir/corona_analysis/annotations/hsflnil1_hg38_sorted.bed
# height = 1
# title = LINE retroelements
# fontsize = 10
# file_type = bed
#
# [Gencode genes]
# file = /input_dir/corona_analysis/annotations/gencode_v38.sorted.bed
# height = 4
# title = Gencode Genes
# fontsize = 8
# file_type = bed
# display = stacked
# labels_in_margin = false
# style = UCSC
# gene_rows = 10
# max_labels = 5000000
#
# [CD8_T_mem_rnaseq_plus]
# file = /input_dir/corona_analysis/tracks/C001HN_CD8_T_mem_rnaseq_plus.bw
# title = RNA CD8 TCell +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [CD8_T_mem_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/C001HN_CD8_T_mem_rnaseq_minus.bw
# title = RNA CD8 TCell -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [BALF_control_plus]
# file = /input_dir/corona_analysis/tracks/BALF_control_s1_rnaseq_minus_hg38.bw
# title = RNA BALF control +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [BALF_control_minus]
# file = /input_dir/corona_analysis/tracks/BALF_control_s1_rnaseq_plus_hg38.bw
# title = RNA BALF control -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# #overlay_previous = share-y
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [BALF_infected_plus]
# file = /input_dir/corona_analysis/tracks/BALF_corona_s1_rnaseq_minus_hg38.bw
# title = RNA BALF CoVid +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [BALF_infected_minus]
# file = /input_dir/corona_analysis/tracks/BALF_corona_s1_rnaseq_plus_hg38.bw
# title = RNA BALF CoVid -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# #overlay_previous = share-y
# show_data_range = true
# file_type = bigwig

# %%
# %%writefile regulatory_architecture_tcell_broad.ini
#
# [x-axis]
# where = top
#
# [CD8 T-Cell1]
# file=/input_dir/corona_analysis/tracks/GSM2827788_CD8T1_hg_t.cool
# title = Tcell S1
# colormap = coolwarm
# min_value = .2
# max_value = 5.2
# depth = 3000000
# transform = log
# show_masked_bins = False
# file_type = hic_matrix
# height = 10
#
# [CD8 T-Cell2]
# file=/input_dir/corona_analysis/tracks/GSM2827789_CD8T2_hg_t.cool
# title = Tcell S2
# colormap = coolwarm
# min_value = .2
# max_value = 5.2
# depth = 3000000
# transform = log
# show_masked_bins = False
# file_type = hic_matrix
# height = 10
#
# #[TAD Calls]
# #file = /input_dir/datavol/epigenetics_tracks/HEK293T_100kbTADs_domains.bed
# #file_type = domains
# #overlay_previous = share-y
# #fontsize = 8
# #line_width = 3
# #border_color = black
# #color = none
#
# [ENCFF518JVS_cd8_tcell_imputed]
# file = /input_dir/corona_analysis/tracks/ENCFF518JVS_cd8_tcell_imputed_hg38.bw
# title = CTCF chip-seq CD8 Tcell imputed
# height = 3
# color = #42f44e
# #overlay previous = yes
# orientation = inverted
# min_value = 2
# max_value = 10
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = True
# file_type = bigwig
#
# [H1 Primed CTCF loops]
# file = /input_dir/corona_analysis/tracks/primed_.7_origami_intra_hg38.arcs
# title = Cohesin Chia-PET in hESC
# compact_level = 1
# color = #00a110
# links_type = arcs
# line_style = solid
# orientation=inverted
# line_width = 1.5
# height = 5
#
# [T-Cell 1 cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_N_T1_scATAC_hg38.bw
# title = [T-Cell 1 cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell EM cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_EM_T_scATAC_hg38.bw
# title = T-Cell EM cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [CD8_MEMORY_PRIMARY_CELLS]
# #file = /input_dir/corona_analysis/tracks/CD8_MEMORY_PRIMARY_CELLS_hg38.bed.gz
# file = /input_dir/corona_analysis/tracks/E048_15_coreMarks_dense_hg38.bed.gz
# fontsize = 8
# height = 1
# title = CD8 Tcell memory cells
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# [COPD GWAS]
# file = /input_dir/corona_analysis/tracks/COPD_GWAS_hg38.bed
# height = 1
# title = COPD GWAS
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [IPF GWAS]
# file = /input_dir/corona_analysis/tracks/ipf_gwas_hg38_allen_5e-8.bed
# height = 1
# title = IPF GWAS
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [CoVid-19_susceptibility]
# file = /input_dir/corona_analysis/tracks/covid_hg38_1e6_susceptibility.bed
# height = 1
# title = CoVid-19 susceptibility 1e-6
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [Ellinghaus CoVid GWAS]
# file = /input_dir/corona_analysis/tracks/Ellinghaus_covid_gwas_hg38.bed
# height = 1
# title = Ellinghaus CoVid GWAS
# color = #e90ef4
# max_labels = 0
# file_type = bed
#
# [LINE elements]
# file = /input_dir/corona_analysis/annotations/hsflnil1_hg38_sorted.bed
# height = 1
# title = LINE retroelements
# fontsize = 10
# file_type = bed
#
# [Gencode genes]
# file = /input_dir/corona_analysis/annotations/gencode_v38.sorted.bed
# height = 4
# title = Gencode Genes
# fontsize = 8
# file_type = bed
# display = stacked
# labels_in_margin = false
# style = UCSC
# gene_rows = 10
# max_labels = 5000000
#
# [CD8_T_mem_rnaseq_plus]
# file = /input_dir/corona_analysis/tracks/C001HN_CD8_T_mem_rnaseq_plus.bw
# title = RNA CD8 TCell +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [CD8_T_mem_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/C001HN_CD8_T_mem_rnaseq_minus.bw
# title = RNA CD8 TCell -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# show_data_range = true
# file_type = bigwig

# %% [markdown]
# # IL2

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr4:122435776-122467762 \
#     --outFileName /input_dir/corona_analysis/out_viz/IL2_cd8t_hg38_fine.pdf

# %% [markdown]
# #

# %% [markdown]
# # Innate immune

# %% [markdown]
# # T-cell differentiation

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr14:98785652-98836861 \
#     --outFileName /input_dir/corona_analysis/out_viz/BCL11b_cd8t_hg38_z1.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr14:98669194-99282480 \
#     --outFileName /input_dir/corona_analysis/out_viz/BCL11b_cd8t_hg38_z2.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_broad.ini \
#     --region chr14:96744521-100430762 \
#     --outFileName /input_dir/corona_analysis/out_viz/BCL11b_cd8t_hg38_z3.pdf
# Out:
# WARNING:pygenometracks.tracksClass:In section 5. [H1 Primed CTCF loops], these parameters are unused:['compact_level']
# INFO:pygenometracks.tracksClass:initialize 1. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 2. [CD8 T-Cell1]
# WARNING:hicmatrix.HiCMatrix:Bin size is not homogeneous.                                       Median 49997
#
# INFO:pygenometracks.tracksClass:initialize 3. [CD8 T-Cell2]
# WARNING:hicmatrix.HiCMatrix:Bin size is not homogeneous.                                       Median 49998
#
# INFO:pygenometracks.tracksClass:initialize 4. [ENCFF518JVS_cd8_tcell_imputed]
# INFO:pygenometracks.tracksClass:initialize 5. [H1 Primed CTCF loops]
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	141974420	141977275	chr7_KI270803v1_alt	421393	422663	0.943
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142303376	142304287	chr7_KI270803v1_alt	421393	422663	0.892
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	340977	341009	0.998
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	374336	375839	0.987
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	499180	500347	0.912
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	340977	341009	chr7	142782517	142784203	0.919
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	142782517	142784203	0.981
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	142812722	142814024	0.974
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	143001731	143004484	0.9
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	143214492	143216079	0.923
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	368583	369846	chr7	142632039	142633527	0.878
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	374336	375839	chr7	143007418	143008973	0.921
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	403791	404916	chr7	143001731	143004484	0.913
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	421393	422663	chr7	142782517	142784203	0.986
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	428100	429398	chr7	142782517	142784203	0.897
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	428100	429398	chr7	143214492	143216079	0.905
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2086999	2087770	chr8_KI270821v1_alt	548587	548592	0.965
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2266587	2267522	chr8_KI270821v1_alt	542877	544402	0.999
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2294945	2296283	chr8_KI270821v1_alt	542877	544402	0.947
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2294945	2296283	chr8_KI270821v1_alt	548587	548592	0.919
#
#
# INFO:pygenometracks.tracksClass:initialize 6. [T-Cell 1 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 7. [T-Cell EM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 8. [CD8_MEMORY_PRIMARY_CELLS]
# 100%|##########| 323581/323581 [00:22<00:00, 14125.62it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [COPD GWAS]
# 100%|##########| 5492/5492 [00:00<00:00, 20416.03it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [IPF GWAS]
# 100%|##########| 3591/3591 [00:00<00:00, 19895.99it/s]
# INFO:pygenometracks.tracksClass:initialize 11. [CoVid-19_susceptibility]
# 100%|##########| 41/41 [00:00<00:00, 24929.90it/s]
# INFO:pygenometracks.tracksClass:initialize 12. [Ellinghaus CoVid GWAS]
# 100%|##########| 60/60 [00:00<00:00, 24887.09it/s]
# INFO:pygenometracks.tracksClass:initialize 13. [LINE elements]
# 100%|##########| 13418/13418 [00:00<00:00, 19560.89it/s]
# INFO:pygenometracks.tracksClass:initialize 14. [Gencode genes]
# 100%|##########| 108610/108610 [00:08<00:00, 12996.86it/s]
# INFO:pygenometracks.tracksClass:initialize 15. [CD8_T_mem_rnaseq_plus]
# INFO:pygenometracks.tracksClass:initialize 16. [CD8_T_mem_rnaseq_minus]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:103.01595735549927
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 50.93085106382979. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [x-axis]
# INFO:pygenometracks.tracksClass:plotting 2. [CD8 T-Cell1]
# INFO:pygenometracks.tracks.GenomeTrack:setting min, max values for track 2. [CD8 T-Cell1] to: 0.2, 5.2
#
# INFO:pygenometracks.tracksClass:plotting 3. [CD8 T-Cell2]
# INFO:pygenometracks.tracks.GenomeTrack:setting min, max values for track 3. [CD8 T-Cell2] to: 0.2, 5.2
#
# INFO:pygenometracks.tracksClass:plotting 4. [ENCFF518JVS_cd8_tcell_imputed]
# INFO:pygenometracks.tracksClass:plotting 5. [H1 Primed CTCF loops]
# DEBUG:pygenometracks.tracks.GenomeTrack:120 were links plotted
# INFO:pygenometracks.tracksClass:plotting 6. [T-Cell 1 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 7. [T-Cell EM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 8. [CD8_MEMORY_PRIMARY_CELLS]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# INFO:pygenometracks.tracksClass:plotting 9. [COPD GWAS]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning* No intervals were found for file /input_dir/corona_analysis/tracks/COPD_GWAS_hg38.bed in section '9. [COPD GWAS]' for the interval plotted (chr14:96744521-100430762).
#
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# INFO:pygenometracks.tracksClass:plotting 10. [IPF GWAS]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# Neither chr14 nor 14 existss as a chromosome name inside the bed file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 11. [CoVid-19_susceptibility]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# Neither chr14 nor 14 existss as a chromosome name inside the bed file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 12. [Ellinghaus CoVid GWAS]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# Neither chr14 nor 14 existss as a chromosome name inside the bed file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 13. [LINE elements]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 3.38,-0.08
# INFO:pygenometracks.tracksClass:plotting 14. [Gencode genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 23.0,-0.08
# INFO:pygenometracks.tracksClass:plotting 15. [CD8_T_mem_rnaseq_plus]
# INFO:pygenometracks.tracksClass:plotting 16. [CD8_T_mem_rnaseq_minus]

# %% [markdown]
# # 3p Loci - CXCR6

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr3:45938415-45955927 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_cxcr6_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr3:45792952-45959481 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_CoVid_suscept_fine_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr3:45864052-45873481 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_CoVid_CRE_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr3:45825952-45875481 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_CoVid_superfine_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_broad.ini \
#     --region chr3:45617381-46677708 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_CoVid_suscept_broad_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_broad.ini \
#     --region chr3:44460745-46446068 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_CoVid_suscept_superbroad_hg38.pdf

# %% [markdown]
# # GSTCD
#
# * chr4:105662395-105894379 # fine hg38
# * chr4:105698396-105727514 # tss hg38
# * chr4:105068288-106695910 # broad hg38

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr4:105698396-105727514 \
#     --outFileName /input_dir/corona_analysis/out_viz/GSTCD_TSS_hg38_cd8T.pdf
# Out:
# INFO:pygenometracks.tracksClass:initialize 1. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 2. [H1 Primed CTCF loops]
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	141974420	141977275	chr7_KI270803v1_alt	421393	422663	0.943
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142303376	142304287	chr7_KI270803v1_alt	421393	422663	0.892
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	340977	341009	0.998
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	374336	375839	0.987
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	499180	500347	0.912
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	340977	341009	chr7	142782517	142784203	0.919
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	142782517	142784203	0.981
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	142812722	142814024	0.974
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	143001731	143004484	0.9
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	143214492	143216079	0.923
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	368583	369846	chr7	142632039	142633527	0.878
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	374336	375839	chr7	143007418	143008973	0.921
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	403791	404916	chr7	143001731	143004484	0.913
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	421393	422663	chr7	142782517	142784203	0.986
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	428100	429398	chr7	142782517	142784203	0.897
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	428100	429398	chr7	143214492	143216079	0.905
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2086999	2087770	chr8_KI270821v1_alt	548587	548592	0.965
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2266587	2267522	chr8_KI270821v1_alt	542877	544402	0.999
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2294945	2296283	chr8_KI270821v1_alt	542877	544402	0.947
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2294945	2296283	chr8_KI270821v1_alt	548587	548592	0.919
#
#
# INFO:pygenometracks.tracksClass:initialize 3. [ENCFF518JVS_cd8_tcell_imputed]
# INFO:pygenometracks.tracksClass:initialize 4. [CD8_effmemT_CPG_meth]
# INFO:pygenometracks.tracksClass:initialize 5. [spacer]
# INFO:pygenometracks.tracksClass:initialize 6. [T-cell CD8 h3k4me3]
# INFO:pygenometracks.tracksClass:initialize 7. [T-cell CD8 H3k27Ac]
# INFO:pygenometracks.tracksClass:initialize 8. [T-cell CD8 H3k9Me3]
# INFO:pygenometracks.tracksClass:initialize 9. [T-Cell 1 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 10. [T-Cell 2 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 11. [T-Cell 3 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 12. [T-Cell EM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 13. [T-Cell CM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 14. [CD8_MEMORY_PRIMARY_CELLS]
# 100%|##########| 323581/323581 [00:23<00:00, 14050.36it/s]
# INFO:pygenometracks.tracksClass:initialize 15. [CD8_NAIVE_PRIMARY_CELLS]
# 100%|##########| 350203/350203 [00:24<00:00, 14025.01it/s]
# INFO:pygenometracks.tracksClass:initialize 16. [spacer]
# INFO:pygenometracks.tracksClass:initialize 17. [COPD GWAS]
# 100%|##########| 5492/5492 [00:00<00:00, 20593.42it/s]
# INFO:pygenometracks.tracksClass:initialize 18. [IPF GWAS]
# 100%|##########| 3591/3591 [00:00<00:00, 19665.14it/s]
# INFO:pygenometracks.tracksClass:initialize 19. [CoVid-19_susceptibility]
# 100%|##########| 41/41 [00:00<00:00, 25393.75it/s]
# INFO:pygenometracks.tracksClass:initialize 20. [Ellinghaus CoVid GWAS]
# 100%|##########| 60/60 [00:00<00:00, 23763.76it/s]
# INFO:pygenometracks.tracksClass:initialize 21. [LINE elements]
# 100%|##########| 13418/13418 [00:00<00:00, 19651.50it/s]
# INFO:pygenometracks.tracksClass:initialize 22. [Gencode genes]
# 100%|##########| 108610/108610 [00:07<00:00, 14392.92it/s]
# INFO:pygenometracks.tracksClass:initialize 23. [CD8_T_mem_rnaseq_plus]
# INFO:pygenometracks.tracksClass:initialize 24. [CD8_T_mem_rnaseq_minus]
# INFO:pygenometracks.tracksClass:initialize 25. [spacer]
# INFO:pygenometracks.tracksClass:initialize 26. [BALF_control_plus]
# INFO:pygenometracks.tracksClass:initialize 27. [BALF_control_minus]
# INFO:pygenometracks.tracksClass:initialize 28. [spacer]
# INFO:pygenometracks.tracksClass:initialize 29. [BALF_infected_plus]
# INFO:pygenometracks.tracksClass:initialize 30. [BALF_infected_minus]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:62.02659201622009
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 56.78191489361703. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [x-axis]
# INFO:pygenometracks.tracksClass:plotting 2. [H1 Primed CTCF loops]
# DEBUG:pygenometracks.tracks.GenomeTrack:1 were links plotted
# INFO:pygenometracks.tracksClass:plotting 3. [ENCFF518JVS_cd8_tcell_imputed]
# INFO:pygenometracks.tracksClass:plotting 4. [CD8_effmemT_CPG_meth]
# INFO:pygenometracks.tracksClass:plotting 5. [spacer]
# INFO:pygenometracks.tracksClass:plotting 6. [T-cell CD8 h3k4me3]
# INFO:pygenometracks.tracksClass:plotting 7. [T-cell CD8 H3k27Ac]
# INFO:pygenometracks.tracksClass:plotting 8. [T-cell CD8 H3k9Me3]
# INFO:pygenometracks.tracksClass:plotting 9. [T-Cell 1 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 10. [T-Cell 2 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 11. [T-Cell 3 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 12. [T-Cell EM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 13. [T-Cell CM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 14. [CD8_MEMORY_PRIMARY_CELLS]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# INFO:pygenometracks.tracksClass:plotting 15. [CD8_NAIVE_PRIMARY_CELLS]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# INFO:pygenometracks.tracksClass:plotting 16. [spacer]
# INFO:pygenometracks.tracksClass:plotting 17. [COPD GWAS]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 3.38,-0.08
# INFO:pygenometracks.tracksClass:plotting 18. [IPF GWAS]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning* No intervals were found for file /input_dir/corona_analysis/tracks/ipf_gwas_hg38_allen_5e-8.bed in section '18. [IPF GWAS]' for the interval plotted (chr4:105698396-105727514).
#
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# INFO:pygenometracks.tracksClass:plotting 19. [CoVid-19_susceptibility]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# Neither chr4 nor 4 existss as a chromosome name inside the bed file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 20. [Ellinghaus CoVid GWAS]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# Neither chr4 nor 4 existss as a chromosome name inside the bed file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 21. [LINE elements]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning* No intervals were found for file /input_dir/corona_analysis/annotations/hsflnil1_hg38_sorted.bed in section '21. [LINE elements]' for the interval plotted (chr4:105698396-105727514).
#
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# INFO:pygenometracks.tracksClass:plotting 22. [Gencode genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 23.0,-0.08
# INFO:pygenometracks.tracksClass:plotting 23. [CD8_T_mem_rnaseq_plus]
# INFO:pygenometracks.tracksClass:plotting 24. [CD8_T_mem_rnaseq_minus]
# INFO:pygenometracks.tracksClass:plotting 25. [spacer]
# INFO:pygenometracks.tracksClass:plotting 26. [BALF_control_plus]
# INFO:pygenometracks.tracksClass:plotting 27. [BALF_control_minus]
# INFO:pygenometracks.tracksClass:plotting 28. [spacer]
# INFO:pygenometracks.tracksClass:plotting 29. [BALF_infected_plus]
# INFO:pygenometracks.tracksClass:plotting 30. [BALF_infected_minus]

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr4:105662395-105894379 \
#     --outFileName /input_dir/corona_analysis/out_viz/GSTCD_gene_hg38_cd8T.pdf
# Out:
# INFO:pygenometracks.tracksClass:initialize 1. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 2. [H1 Primed CTCF loops]
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	141974420	141977275	chr7_KI270803v1_alt	421393	422663	0.943
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142303376	142304287	chr7_KI270803v1_alt	421393	422663	0.892
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	340977	341009	0.998
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	374336	375839	0.987
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	499180	500347	0.912
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	340977	341009	chr7	142782517	142784203	0.919
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	142782517	142784203	0.981
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	142812722	142814024	0.974
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	143001731	143004484	0.9
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	143214492	143216079	0.923
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	368583	369846	chr7	142632039	142633527	0.878
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	374336	375839	chr7	143007418	143008973	0.921
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	403791	404916	chr7	143001731	143004484	0.913
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	421393	422663	chr7	142782517	142784203	0.986
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	428100	429398	chr7	142782517	142784203	0.897
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	428100	429398	chr7	143214492	143216079	0.905
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2086999	2087770	chr8_KI270821v1_alt	548587	548592	0.965
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2266587	2267522	chr8_KI270821v1_alt	542877	544402	0.999
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2294945	2296283	chr8_KI270821v1_alt	542877	544402	0.947
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2294945	2296283	chr8_KI270821v1_alt	548587	548592	0.919
#
#
# INFO:pygenometracks.tracksClass:initialize 3. [ENCFF518JVS_cd8_tcell_imputed]
# INFO:pygenometracks.tracksClass:initialize 4. [CD8_effmemT_CPG_meth]
# INFO:pygenometracks.tracksClass:initialize 5. [spacer]
# INFO:pygenometracks.tracksClass:initialize 6. [T-cell CD8 h3k4me3]
# INFO:pygenometracks.tracksClass:initialize 7. [T-cell CD8 H3k27Ac]
# INFO:pygenometracks.tracksClass:initialize 8. [T-cell CD8 H3k9Me3]
# INFO:pygenometracks.tracksClass:initialize 9. [T-Cell 1 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 10. [T-Cell 2 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 11. [T-Cell 3 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 12. [T-Cell EM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 13. [T-Cell CM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 14. [CD8_MEMORY_PRIMARY_CELLS]
# 100%|##########| 323581/323581 [00:21<00:00, 14714.56it/s]
# INFO:pygenometracks.tracksClass:initialize 15. [CD8_NAIVE_PRIMARY_CELLS]
# 100%|##########| 350203/350203 [00:23<00:00, 14593.20it/s]
# INFO:pygenometracks.tracksClass:initialize 16. [spacer]
# INFO:pygenometracks.tracksClass:initialize 17. [COPD GWAS]
# 100%|##########| 5492/5492 [00:00<00:00, 21346.84it/s]
# INFO:pygenometracks.tracksClass:initialize 18. [IPF GWAS]
# 100%|##########| 3591/3591 [00:00<00:00, 20577.70it/s]
# INFO:pygenometracks.tracksClass:initialize 19. [CoVid-19_susceptibility]
# 100%|##########| 41/41 [00:00<00:00, 24507.12it/s]
# INFO:pygenometracks.tracksClass:initialize 20. [Ellinghaus CoVid GWAS]
# 100%|##########| 60/60 [00:00<00:00, 25338.12it/s]
# INFO:pygenometracks.tracksClass:initialize 21. [LINE elements]
# 100%|##########| 13418/13418 [00:00<00:00, 20377.01it/s]
# INFO:pygenometracks.tracksClass:initialize 22. [Gencode genes]
# 100%|##########| 108610/108610 [00:07<00:00, 14811.43it/s]
# INFO:pygenometracks.tracksClass:initialize 23. [CD8_T_mem_rnaseq_plus]
# INFO:pygenometracks.tracksClass:initialize 24. [CD8_T_mem_rnaseq_minus]
# INFO:pygenometracks.tracksClass:initialize 25. [spacer]
# INFO:pygenometracks.tracksClass:initialize 26. [BALF_control_plus]
# INFO:pygenometracks.tracksClass:initialize 27. [BALF_control_minus]
# INFO:pygenometracks.tracksClass:initialize 28. [spacer]
# INFO:pygenometracks.tracksClass:initialize 29. [BALF_infected_plus]
# INFO:pygenometracks.tracksClass:initialize 30. [BALF_infected_minus]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:59.623852491378784
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 56.78191489361703. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [x-axis]
# INFO:pygenometracks.tracksClass:plotting 2. [H1 Primed CTCF loops]
# DEBUG:pygenometracks.tracks.GenomeTrack:3 were links plotted
# INFO:pygenometracks.tracksClass:plotting 3. [ENCFF518JVS_cd8_tcell_imputed]
# INFO:pygenometracks.tracksClass:plotting 4. [CD8_effmemT_CPG_meth]
# INFO:pygenometracks.tracksClass:plotting 5. [spacer]
# INFO:pygenometracks.tracksClass:plotting 6. [T-cell CD8 h3k4me3]
# INFO:pygenometracks.tracksClass:plotting 7. [T-cell CD8 H3k27Ac]
# INFO:pygenometracks.tracksClass:plotting 8. [T-cell CD8 H3k9Me3]
# INFO:pygenometracks.tracksClass:plotting 9. [T-Cell 1 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 10. [T-Cell 2 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 11. [T-Cell 3 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 12. [T-Cell EM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 13. [T-Cell CM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 14. [CD8_MEMORY_PRIMARY_CELLS]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# INFO:pygenometracks.tracksClass:plotting 15. [CD8_NAIVE_PRIMARY_CELLS]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# INFO:pygenometracks.tracksClass:plotting 16. [spacer]
# INFO:pygenometracks.tracksClass:plotting 17. [COPD GWAS]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 14.879999999999999,-0.08
# INFO:pygenometracks.tracksClass:plotting 18. [IPF GWAS]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning* No intervals were found for file /input_dir/corona_analysis/tracks/ipf_gwas_hg38_allen_5e-8.bed in section '18. [IPF GWAS]' for the interval plotted (chr4:105662395-105894379).
#
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# INFO:pygenometracks.tracksClass:plotting 19. [CoVid-19_susceptibility]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# Neither chr4 nor 4 existss as a chromosome name inside the bed file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 20. [Ellinghaus CoVid GWAS]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# Neither chr4 nor 4 existss as a chromosome name inside the bed file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 21. [LINE elements]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 5.68,-0.08
# INFO:pygenometracks.tracksClass:plotting 22. [Gencode genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 23.0,-0.08
# INFO:pygenometracks.tracksClass:plotting 23. [CD8_T_mem_rnaseq_plus]
# INFO:pygenometracks.tracksClass:plotting 24. [CD8_T_mem_rnaseq_minus]
# INFO:pygenometracks.tracksClass:plotting 25. [spacer]
# INFO:pygenometracks.tracksClass:plotting 26. [BALF_control_plus]
# INFO:pygenometracks.tracksClass:plotting 27. [BALF_control_minus]
# INFO:pygenometracks.tracksClass:plotting 28. [spacer]
# INFO:pygenometracks.tracksClass:plotting 29. [BALF_infected_plus]
# INFO:pygenometracks.tracksClass:plotting 30. [BALF_infected_minus]

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_broad.ini \
#     --region chr4:104211178-106300000 \
#     --outFileName /input_dir/corona_analysis/out_viz/GSTCD_broad_hg38_cd8T.pdf
# Out:
# WARNING:pygenometracks.tracksClass:In section 5. [H1 Primed CTCF loops], these parameters are unused:['compact_level']
# INFO:pygenometracks.tracksClass:initialize 1. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 2. [CD8 T-Cell1]
# WARNING:hicmatrix.HiCMatrix:Bin size is not homogeneous.                                       Median 49997
#
# INFO:pygenometracks.tracksClass:initialize 3. [CD8 T-Cell2]
# WARNING:hicmatrix.HiCMatrix:Bin size is not homogeneous.                                       Median 49998
#
# INFO:pygenometracks.tracksClass:initialize 4. [ENCFF518JVS_cd8_tcell_imputed]
# INFO:pygenometracks.tracksClass:initialize 5. [H1 Primed CTCF loops]
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	141974420	141977275	chr7_KI270803v1_alt	421393	422663	0.943
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142303376	142304287	chr7_KI270803v1_alt	421393	422663	0.892
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	340977	341009	0.998
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	374336	375839	0.987
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7	142338172	142339623	chr7_KI270803v1_alt	499180	500347	0.912
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	340977	341009	chr7	142782517	142784203	0.919
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	142782517	142784203	0.981
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	142812722	142814024	0.974
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	143001731	143004484	0.9
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	359102	359255	chr7	143214492	143216079	0.923
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	368583	369846	chr7	142632039	142633527	0.878
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	374336	375839	chr7	143007418	143008973	0.921
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	403791	404916	chr7	143001731	143004484	0.913
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	421393	422663	chr7	142782517	142784203	0.986
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	428100	429398	chr7	142782517	142784203	0.897
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr7_KI270803v1_alt	428100	429398	chr7	143214492	143216079	0.905
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2086999	2087770	chr8_KI270821v1_alt	548587	548592	0.965
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2266587	2267522	chr8_KI270821v1_alt	542877	544402	0.999
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2294945	2296283	chr8_KI270821v1_alt	542877	544402	0.947
#
#
# WARNING:pygenometracks.tracks.GenomeTrack:Only links in same chromosome are used. Skipping line
# chr8	2294945	2296283	chr8_KI270821v1_alt	548587	548592	0.919
#
#
# INFO:pygenometracks.tracksClass:initialize 6. [T-Cell 1 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 7. [T-Cell EM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:initialize 8. [CD8_MEMORY_PRIMARY_CELLS]
# 100%|##########| 323581/323581 [00:22<00:00, 14441.13it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [COPD GWAS]
# 100%|##########| 5492/5492 [00:00<00:00, 20506.28it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [IPF GWAS]
# 100%|##########| 3591/3591 [00:00<00:00, 20104.90it/s]
# INFO:pygenometracks.tracksClass:initialize 11. [CoVid-19_susceptibility]
# 100%|##########| 41/41 [00:00<00:00, 24430.52it/s]
# INFO:pygenometracks.tracksClass:initialize 12. [Ellinghaus CoVid GWAS]
# 100%|##########| 60/60 [00:00<00:00, 24943.82it/s]
# INFO:pygenometracks.tracksClass:initialize 13. [LINE elements]
# 100%|##########| 13418/13418 [00:00<00:00, 19622.81it/s]
# INFO:pygenometracks.tracksClass:initialize 14. [Gencode genes]
# 100%|##########| 108610/108610 [00:08<00:00, 13159.06it/s]
# INFO:pygenometracks.tracksClass:initialize 15. [CD8_T_mem_rnaseq_plus]
# INFO:pygenometracks.tracksClass:initialize 16. [CD8_T_mem_rnaseq_minus]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:102.73052930831909
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 50.93085106382979. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [x-axis]
# INFO:pygenometracks.tracksClass:plotting 2. [CD8 T-Cell1]
# WARNING:pygenometracks.tracks.HiCMatrixTrack:The depth was set to 3000000 which is more than 125% of the region plotted. The depth will be set to 2611027
# INFO:pygenometracks.tracks.GenomeTrack:setting min, max values for track 2. [CD8 T-Cell1] to: 0.2, 5.2
#
# INFO:pygenometracks.tracksClass:plotting 3. [CD8 T-Cell2]
# WARNING:pygenometracks.tracks.HiCMatrixTrack:The depth was set to 3000000 which is more than 125% of the region plotted. The depth will be set to 2611027
# INFO:pygenometracks.tracks.GenomeTrack:setting min, max values for track 3. [CD8 T-Cell2] to: 0.2, 5.2
#
# INFO:pygenometracks.tracksClass:plotting 4. [ENCFF518JVS_cd8_tcell_imputed]
# INFO:pygenometracks.tracksClass:plotting 5. [H1 Primed CTCF loops]
# DEBUG:pygenometracks.tracks.GenomeTrack:23 were links plotted
# INFO:pygenometracks.tracksClass:plotting 6. [T-Cell 1 cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 7. [T-Cell EM cluster scATAC-seq]
# INFO:pygenometracks.tracksClass:plotting 8. [CD8_MEMORY_PRIMARY_CELLS]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# INFO:pygenometracks.tracksClass:plotting 9. [COPD GWAS]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 58.57999999999999,-0.08
# INFO:pygenometracks.tracksClass:plotting 10. [IPF GWAS]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning* No intervals were found for file /input_dir/corona_analysis/tracks/ipf_gwas_hg38_allen_5e-8.bed in section '10. [IPF GWAS]' for the interval plotted (chr4:104211178-106300000).
#
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# INFO:pygenometracks.tracksClass:plotting 11. [CoVid-19_susceptibility]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# Neither chr4 nor 4 existss as a chromosome name inside the bed file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 12. [Ellinghaus CoVid GWAS]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# Neither chr4 nor 4 existss as a chromosome name inside the bed file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 13. [LINE elements]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 10.28,-0.08
# INFO:pygenometracks.tracksClass:plotting 14. [Gencode genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 23.0,-0.08
# INFO:pygenometracks.tracksClass:plotting 15. [CD8_T_mem_rnaseq_plus]
# INFO:pygenometracks.tracksClass:plotting 16. [CD8_T_mem_rnaseq_minus]
