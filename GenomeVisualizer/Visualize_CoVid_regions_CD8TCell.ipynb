# %%
# %%writefile regulatory_architecture_tcell_fine.ini
#
# [x-axis]
# where = top
#
# [H1 Primed CTCF loops]
# file = /input_dir/corona_analysis/tracks/primed_.7_origami_intra_hg38.arcs
# title = Cohesin Chia-PET
# color = #00a110
# links_type = arcs
# ylim = 300000
# line_style = solid
# line_width = 1.5
# height = 5
#
# #[CTCF NN variants]
# #file =
# #title = Variants CTCF perturbing
# #height = 1
# #color = #e90ef4
# #max_labels = 0
# #labels = false
# #file_type = bed
#
# [ENCFF518JVS_cd8_tcell_imputed]
# file = /input_dir/corona_analysis/tracks/ENCFF518JVS_cd8_tcell_imputed_hg38.bw
# title = CTCF chip-seq CD8 Tcell imputed
# height = 3
# color = #42f44e
# #overlay previous = yes
# orientation = inverted
# min_value = 2
# max_value = 10
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = True
# file_type = bigwig
#
# [CD8_effmemT_CPG_meth]
# file = /input_dir/corona_analysis/tracks/S002ND51_CD8_effmemT_CPG_meth_hg38.bw
# title = CD8+ eff memory T-cell C-meth
# height = .5
# color = #21ffff
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [T-cell CD8 h3k4me3]
# file = /input_dir/corona_analysis/tracks/C0054X_cd8_tcell_h3k4me3_hg38.bw
# title = CD8 T-cell H3k4Me3 fc Chip-seq
# height = 2
# color = #ffb42b
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-cell CD8 H3k27Ac]
# file = /input_dir/corona_analysis/tracks/C0054X_cd8_tcell_h3k27Ac_hg38.bw
# title = CD8 T-cell H3k27Ac fc Chip-seq
# height = 2
# color = #42f4f4
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-cell CD8 H3k9Me3]
# file = /input_dir/corona_analysis/tracks/C0054X_cd8_tcell_h3k9me3_hg38.bw
# title = CD8 T-cell H3k9Me3 fc Chip-seq
# height = 2
# color = #a22eea
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell 1 cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_N_T1_scATAC_hg38.bw
# title = [T-Cell 1 cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell 2 cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_N_T2_scATAC_hg38.bw
# title = [T-Cell 2 cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell 3 cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_N_T3_scATAC_hg38.bw
# title = T-Cell 3 cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell EM cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_EM_T_scATAC_hg38.bw
# title = T-Cell EM cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell CM cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_CM_T_scATAC_hg38.bw
# title = T-Cell CM cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [CD8_MEMORY_PRIMARY_CELLS]
# #file = /input_dir/corona_analysis/tracks/CD8_MEMORY_PRIMARY_CELLS_hg38.bed.gz
# file = /input_dir/corona_analysis/tracks/E048_15_coreMarks_dense_hg38.bed.gz
# fontsize = 8
# height = 1
# title = CD8 Tcell memory cells
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# [CD8_NAIVE_PRIMARY_CELLS]
# #file = /input_dir/corona_analysis/tracks/CD8_NAIVE_PRIMARY_CELLS_hg38.bed.gz
# file = /input_dir/corona_analysis/tracks/E047_15_coreMarks_dense_hg38.bed.gz
# fontsize = 8
# height = 1
# title = CD8 Tcell naive cells
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# [G-quadruplex 93T449]
# file = /input_dir/corona_analysis/tracks/GSE145535_RAW/GSM4320548_ChIPseq_IP_BG4_rep2_93T449_m1.ucsc.bigWig
# second_file = /input_dir/corona_analysis/tracks/GSE145535_RAW/GSM4320549_ChIPseq_Input_BG4_rep2_93T449_m1.ucsc.bigWig
# title = G-quadruplex Liposarcoma (93T449)
# operation = log2((1 + file) / (1 + second_file))
# height = 2
# color = #2a42f9
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [G-quadruplex HaCat]
# file = /input_dir/corona_analysis/tracks/GSE99205_common_HaCaT_G4_ChIP_peaks_RNase_treated_hg38.bed
# height = 1
# title = G-quadruplex HaCat peaks
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [spacer]
# height = 1
#
# [Mckay SCLC GWAS]
# file = /input_dir/corona_analysis/tracks/mckay_2017_sclc_overall_hg38.bed
# height = 1
# title = Mckay SCLC GWAS
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [Wu SCLC GWAS]
# file = /input_dir/corona_analysis/tracks/gwas_catalog_sclc_hg38.bed
# height = 1
# title = Wu SCLC GWAS
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [COPD GWAS]
# file = /input_dir/corona_analysis/tracks/COPD_GWAS_hg38.bed
# height = 1
# title = COPD GWAS
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [IPF GWAS]
# file = /input_dir/corona_analysis/tracks/ipf_gwas_hg38_allen_5e-8.bed
# height = 1
# title = IPF GWAS
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [CoVid-19_susceptibility]
# file = /input_dir/corona_analysis/tracks/covid_hg38_1e6_susceptibility.bed
# height = 1
# title = CoVid-19 susceptibility 1e-6
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [Ellinghaus CoVid GWAS]
# file = /input_dir/corona_analysis/tracks/Ellinghaus_covid_gwas_hg38.bed
# height = 1
# title = Ellinghaus CoVid GWAS
# color = #e90ef4
# max_labels = 0
# file_type = bed
#
# [DTI sgRNAs]
# file = /input_dir/corona_analysis/tracks/DTI_plasmids/DTI_all_plasmids_hg38.bed
# height = 2
# title = DTI sgRNAs
# fontsize = 7
# file_type = bed
# max_labels = 1000
# color = #0dfff3
#
# #[ClinVar kidney phenotype]
# #file = /input_dir/datavol/epigenetics_tracks/clinvar_kidney_variants_hg38.bed
# #height = 1
# #title = ClinVar w/ immune phenotype
# #color = #e90ef4
# #max_labels = 0
# #file_type = bed
# #fontsize = 10
#
# [LINE elements]
# file = /input_dir/corona_analysis/annotations/hsflnil1_hg38_sorted.bed
# height = 1
# title = LINE retroelements
# fontsize = 10
# file_type = bed
#
# [Repeatmasker]
# file = /input_dir/corona_analysis/annotations/human/hg38_2020_rmsk_sorted_filt_col.bed
# height = 1
# title = Repeats
# color = bed_rgb
# border_color = bed_rgb
# max_labels = 0
# file_type = bed
# display = collapsed
# gene_rows = 4
#
# [Gencode genes]
# file = /input_dir/corona_analysis/annotations/gencode_v38.sorted.bed
# height = 4
# title = Gencode Genes
# fontsize = 8
# file_type = bed
# display = stacked
# labels_in_margin = false
# style = UCSC
# gene_rows = 10
# max_labels = 5000000
#
# [CD8_T_mem_rnaseq_plus]
# file = /input_dir/corona_analysis/tracks/C001HN_CD8_T_mem_rnaseq_plus.bw
# title = RNA CD8 TCell +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [CD8_T_mem_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/C001HN_CD8_T_mem_rnaseq_minus.bw
# title = RNA CD8 TCell -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [BALF_control_plus]
# file = /input_dir/corona_analysis/tracks/BALF_control_s1_rnaseq_minus_hg38.bw
# title = RNA BALF control +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [BALF_control_minus]
# file = /input_dir/corona_analysis/tracks/BALF_control_s1_rnaseq_plus_hg38.bw
# title = RNA BALF control -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# #overlay_previous = share-y
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [BALF_infected_plus]
# file = /input_dir/corona_analysis/tracks/BALF_corona_s1_rnaseq_minus_hg38.bw
# title = RNA BALF CoVid +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [BALF_infected_minus]
# file = /input_dir/corona_analysis/tracks/BALF_corona_s1_rnaseq_plus_hg38.bw
# title = RNA BALF CoVid -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# #overlay_previous = share-y
# show_data_range = true
# file_type = bigwig

# %%
# %%writefile regulatory_architecture_tcell_broad.ini
#
# [x-axis]
# where = top
#
# [CD8 T-Cell1]
# file=/input_dir/corona_analysis/tracks/GSM2827788_CD8T1_hg_t.cool
# title = Tcell S1
# colormap = coolwarm
# min_value = .2
# max_value = 5.2
# depth = 3000000
# transform = log
# show_masked_bins = False
# file_type = hic_matrix
# height = 10
#
# [CD8 T-Cell2]
# file=/input_dir/corona_analysis/tracks/GSM2827789_CD8T2_hg_t.cool
# title = Tcell S2
# colormap = coolwarm
# min_value = .2
# max_value = 5.2
# depth = 3000000
# transform = log
# show_masked_bins = False
# file_type = hic_matrix
# height = 10
#
# #[TAD Calls]
# #file = /input_dir/datavol/epigenetics_tracks/HEK293T_100kbTADs_domains.bed
# #file_type = domains
# #overlay_previous = share-y
# #fontsize = 8
# #line_width = 3
# #border_color = black
# #color = none
#
# [ENCFF518JVS_cd8_tcell_imputed]
# file = /input_dir/corona_analysis/tracks/ENCFF518JVS_cd8_tcell_imputed_hg38.bw
# title = CTCF chip-seq CD8 Tcell imputed
# height = 3
# color = #42f44e
# #overlay previous = yes
# orientation = inverted
# min_value = 2
# max_value = 10
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = True
# file_type = bigwig
#
# [H1 Primed CTCF loops]
# file = /input_dir/corona_analysis/tracks/primed_.7_origami_intra_hg38.arcs
# title = Cohesin Chia-PET in hESC
# compact_level = 1
# color = #00a110
# links_type = arcs
# line_style = solid
# orientation=inverted
# line_width = 1.5
# height = 5
#
# [T-Cell 1 cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_N_T1_scATAC_hg38.bw
# title = [T-Cell 1 cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [T-Cell EM cluster scATAC-seq]
# file = /input_dir/corona_analysis/tracks/CD8_EM_T_scATAC_hg38.bw
# title = T-Cell EM cluster scATAC-seq
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [CD8_MEMORY_PRIMARY_CELLS]
# #file = /input_dir/corona_analysis/tracks/CD8_MEMORY_PRIMARY_CELLS_hg38.bed.gz
# file = /input_dir/corona_analysis/tracks/E048_15_coreMarks_dense_hg38.bed.gz
# fontsize = 8
# height = 1
# title = CD8 Tcell memory cells
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# [COPD GWAS]
# file = /input_dir/corona_analysis/tracks/COPD_GWAS_hg38.bed
# height = 1
# title = COPD GWAS
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [IPF GWAS]
# file = /input_dir/corona_analysis/tracks/ipf_gwas_hg38_allen_5e-8.bed
# height = 1
# title = IPF GWAS
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [CoVid-19_susceptibility]
# file = /input_dir/corona_analysis/tracks/covid_hg38_1e6_susceptibility.bed
# height = 1
# title = CoVid-19 susceptibility 1e-6
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [Ellinghaus CoVid GWAS]
# file = /input_dir/corona_analysis/tracks/Ellinghaus_covid_gwas_hg38.bed
# height = 1
# title = Ellinghaus CoVid GWAS
# color = #e90ef4
# max_labels = 0
# file_type = bed
#
# [LINE elements]
# file = /input_dir/corona_analysis/annotations/hsflnil1_hg38_sorted.bed
# height = 1
# title = LINE retroelements
# fontsize = 10
# file_type = bed
#
# [Gencode genes]
# file = /input_dir/corona_analysis/annotations/gencode_v38.sorted.bed
# height = 4
# title = Gencode Genes
# fontsize = 8
# file_type = bed
# display = stacked
# labels_in_margin = false
# style = UCSC
# gene_rows = 10
# max_labels = 5000000
#
# [CD8_T_mem_rnaseq_plus]
# file = /input_dir/corona_analysis/tracks/C001HN_CD8_T_mem_rnaseq_plus.bw
# title = RNA CD8 TCell +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [CD8_T_mem_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/C001HN_CD8_T_mem_rnaseq_minus.bw
# title = RNA CD8 TCell -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# show_data_range = true
# file_type = bigwig

# %% [markdown]
# # IL2

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr4:122435776-122467762 \
#     --outFileName /input_dir/corona_analysis/out_viz/IL2_cd8t_hg38_fine.pdf

# %% [markdown]
# #

# %% [markdown]
# # Innate immune

# %% [markdown]
# # T-cell differentiation

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr14:98785652-98836861 \
#     --outFileName /input_dir/corona_analysis/out_viz/BCL11b_cd8t_hg38_z1.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr14:98669194-99282480 \
#     --outFileName /input_dir/corona_analysis/out_viz/BCL11b_cd8t_hg38_z2.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_broad.ini \
#     --region chr14:96744521-100430762 \
#     --outFileName /input_dir/corona_analysis/out_viz/BCL11b_cd8t_hg38_z3.pdf

# %% [markdown]
# # 3p Loci - CXCR6

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr3:45938415-45955927 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_cxcr6_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr3:45792952-45959481 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_CoVid_suscept_fine_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr3:45864052-45873481 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_CoVid_CRE_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr3:45825952-45875481 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_CoVid_superfine_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_broad.ini \
#     --region chr3:45617381-46677708 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_CoVid_suscept_broad_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_broad.ini \
#     --region chr3:44460745-46446068 \
#     --outFileName /input_dir/corona_analysis/out_viz/chr3p_cd8T_CoVid_suscept_superbroad_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr13:28239868-28624208 \
#     --outFileName /input_dir/corona_analysis/out_viz/FLT1_gene_cd8T_hg38.pdf

# %% [markdown]
# # GSTCD
#
# * chr4:105662395-105894379 # fine hg38
# * chr4:105698396-105727514 # tss hg38
# * chr4:105068288-106695910 # broad hg38

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr4:105698396-105727514 \
#     --outFileName /input_dir/corona_analysis/out_viz/GSTCD_TSS_hg38_cd8T.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr4:105662395-105894379 \
#     --outFileName /input_dir/corona_analysis/out_viz/GSTCD_gene_hg38_cd8T.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_broad.ini \
#     --region chr4:104211178-106300000 \
#     --outFileName /input_dir/corona_analysis/out_viz/GSTCD_broad_hg38_cd8T.pdf

# %% [markdown]
# ## Sepsis loci

# %%
# %%bash
# pyGenomeTracks --tracks regulatory_architecture_tcell_broad.ini \
#     --region chr2:217951780-218733030 \
#     --outFileName /input_dir/corona_analysis/out_viz/Sepsis_chr2_TAD_hg38_CD8T.pdf

# %% [markdown]
# ## CXCR1 and CXCR2

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr2:218102005-218181563 \
#     --outFileName /input_dir/corona_analysis/out_viz/CXCR1_CXCR2_gene_hg38_CD8T.pdf

# %% [markdown]
# ### IRF8

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr16:85885875-85935536 \
#     --outFileName /input_dir/corona_analysis/out_viz/IRF8_gene_hg38_CD8T.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_broad.ini \
#     --region chr16:85772366-87727999 \
#     --outFileName /input_dir/corona_analysis/out_viz/Sepsis_chr16_TAD_hg38_CD8T.pdf

# %% [markdown]
# ## FLT1

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr13:28493296-28497474 \
#     --outFileName /input_dir/corona_analysis/out_viz/FLT1_tss_hg38_CD8T.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_fine.ini \
#     --region chr13:28299056-28523129 \
#     --outFileName /input_dir/corona_analysis/out_viz/FLT1_gene_hg38_CD8T.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_tcell_broad.ini \
#     --region chr13:28282194-28971377 \
#     --outFileName /input_dir/corona_analysis/out_viz/FLT1_TAD_hg38_CD8T.pdf
