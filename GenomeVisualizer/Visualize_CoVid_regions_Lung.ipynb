# %%
# %%writefile regulatory_architecture_lung_fine.ini
#
# [x-axis]
# where = top
#
# [H1 Primed CTCF loops]
# file = /input_dir/corona_analysis/tracks/primed_.7_origami_intra.arcs
# title = Cohesin Chia-PET
# color = #00a110
# links_type = arcs
# ylim = 3000000
# line_style = solid
# line_width = 1.5
# height = 5
#
# #[CTCF NN variants]
# #file =
# #title = Variants CTCF perturbing
# #height = 1
# #color = #e90ef4
# #max_labels = 0
# #labels = false
# #file_type = bed
#
# [ENCFF117BRM_CTCF_NHLF]
# file = /input_dir/corona_analysis/tracks/ENCFF117BRM_CTCF_NHLF.bw
# title = CTCF chip-seq
# height = 2
# color = #42f44e
# orientation = inverted
# min_value = 2
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# #[GSE50874_tubule_avg_methylation]
# #file=/input_dir/datavol/epigenetics_tracks/GSE50874_tubule_avg_methylation.bw
# #title = Methylation tubules
# #height = .5
# #color = #21ffff
# #min_value = 0
# #number_of_bins = 500
# #nans_to_zeros = True
# #summary_method = mean
# #orientation = inverted
# #show_data_range = true
# #file_type = bigwig
#
# [spacer]
# height = 1
#
# [ENCFF782BOR_H3k4Me3_SAEC]
# file = /input_dir/corona_analysis/tracks/ENCFF782BOR_H3k4Me3_SAEC.bw
# title = H3k4Me3 fc Chip-seq
# height = 2
# color = #ffb42b
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [ENCFF637KNN_H3k27Ac_NHLF]
# file = /input_dir/corona_analysis/tracks/ENCFF637KNN_H3k27Ac_NHLF.bw
# title = H3k27Ac fc Chip-seq
# height = 2
# color = #42f4f4
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [ENCFF143LCY_H3k9Me3_NHLF]
# file = /input_dir/corona_analysis/tracks/ENCFF143LCY_H3k9Me3_NHLF.bw
# title = H3k9Me3 fc Chip-seq
# height = 2
# color = #a22eea
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [NHLF Chromatin state]
# file = /input_dir/corona_analysis/tracks/E128_15_coreMarks_dense.bed.gz
# fontsize = 8
# height = 1
# title = NHLF Chromatin State
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# [DNAse Peaks SAEC]
# file = /input_dir/corona_analysis/tracks/ENCFF827VFY_DNAse_SAEC.bed
# title = DNAse Peaks SAEC
# file_type = narrow_peak
# height = 1
# line_width = 1
# labels = false
# show_labels = false
# color = #1d6ae5
# display = collapsed
# fontsize = 10
#
# [ENCFF827VFY_DNAse_SAEC]
# file = /input_dir/corona_analysis/tracks/ENCFF827VFY_DNAse_SAEC.bw
# title = DNase sensitivity
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [CoVid-19_susceptibility]
# file = /input_dir/corona_analysis/tracks/covid_hg38_1e6_susceptibility.bed
# height = 1
# title = CoVid-19 susceptibility 1e-6
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [Ellinghaus CoVid GWAS]
# file = /input_dir/corona_analysis/tracks/Ellinghaus_covid_gwas_hg38.bed
# height = 1
# title = Ellinghaus CoVid GWAS
# color = #e90ef4
# max_labels = 0
# file_type = bed
#
# #[ClinVar kidney phenotype]
# #file = /input_dir/datavol/epigenetics_tracks/clinvar_kidney_variants_hg19.bed
# #height = 1
# #title = ClinVar w/ kidney phenotype
# #color = #e90ef4
# #max_labels = 0
# #file_type = bed
# #fontsize = 10
#
# [LINE elements]
# file = /input_dir/corona_analysis/annotations/hsflnil1_hg38_sorted.bed
# height = 1
# title = LINE retroelements
# fontsize = 10
# file_type = bed
#
# [Gencode genes]
# file = /input_dir/corona_analysis/annotations/gencode_v38.sorted.bed
# height = 4
# title = Gencode Genes
# fontsize = 8
# file_type = bed
# display = stacked
# labels_in_margin = false
# style = UCSC
# gene_rows = 10
# max_labels = 5000000
#
# #[ENCFF730XSB_HBEC_rnaseq_plus]
# #file = /input_dir/corona_analysis/tracks/NCFF322WTN_HBEC_rnaseq_plus.bw
# #title = RNA HBEC +
# #height = 2
# #color = #ef1a1a
# #min_value = 0
# #number_of_bins = 500
# #nans_to_zeros = True
# #summary_method = mean
# #show_data_range = true
# #file_type = bigwig
# #
# #[ENCFF730XSB_HBEC_rnaseq_minus]
# #file = /input_dir/corona_analysis/tracks/ENCFF730XSB_HBEC_rnaseq_minus.bw
# #title = RNA HBEC -
# #height = 2
# #color = #ef1a1a
# #min_value = 0
# #number_of_bins = 500
# #nans_to_zeros = True
# #summary_method = mean
# ##overlay_previous = share-y
# #orientation = inverted
# #show_data_range = true
# #file_type = bigwig
#
# [ENCFF121EOD_NHLF_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/ENCFF996XPQ_NHLF_rnaseq_plus_hg38.bw
# title = RNA NHLF +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [ENCFF121EOD_NHLF_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/ENCFF121EOD_NHLF_rnaseq_minus_hg38.bw
# title = RNA NHLF -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# #overlay_previous = share-y
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [BALF_control_plus]
# file = /input_dir/corona_analysis/tracks/BALF_control_s1_rnaseq_minus_hg38.bw
# title = RNA BALF control +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [BALF_control_minus]
# file = /input_dir/corona_analysis/tracks/BALF_control_s1_rnaseq_plus_hg38.bw
# title = RNA BALF control -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# #overlay_previous = share-y
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [BALF_infected_plus]
# file = /input_dir/corona_analysis/tracks/BALF_corona_s1_rnaseq_minus_hg38.bw
# title = RNA BALF CoVid +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [BALF_infected_minus]
# file = /input_dir/corona_analysis/tracks/BALF_corona_s1_rnaseq_plus_hg38.bw
# title = RNA BALF CoVid -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# #overlay_previous = share-y
# show_data_range = true
# file_type = bigwig

# %%
# %%writefile regulatory_architecture_lung_broad.ini
#
# [x-axis]
# where = top
#
# [IMR90 In-situ Hi-C]
# file=/input_dir/corona_analysis/tracks/4DNFIH7TH4MF_50kb_50000.cool
# title = IMR90 In-situ Hi-C
# colormap = coolwarm
# min_value = 1.2
# max_value = 8
# depth = 3000000
# transform = log
# show_masked_bins = False
# file_type = hic_matrix
# height = 10
#
# #[TAD Calls]
# #file = /input_dir/datavol/epigenetics_tracks/HEK293T_100kbTADs_domains.bed
# #file_type = domains
# #overlay_previous = share-y
# #fontsize = 8
# #line_width = 3
# #border_color = black
# #color = none
#
# [H1 Primed CTCF loops]
# file = /input_dir/corona_analysis/tracks/primed_.7_origami_intra.arcs
# title = Cohesin Chia-PET
# color = #00a110
# links_type = arcs
# line_style = solid
# orientation=inverted
# line_width = 1.5
# height = 5
#
# [ENCFF827VFY_DNAse_SAEC]
# file = /input_dir/corona_analysis/tracks/ENCFF827VFY_DNAse_SAEC.bw
# title = DNase sensitivity
# height = 3
# color = #2a42f9
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = True
# file_type = bigwig
#
# [NHLF Chromatin state]
# file = /input_dir/corona_analysis/tracks/E128_15_coreMarks_dense.bed.gz
# fontsize = 8
# height = 1
# title = NHLF Chromatin State
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# [CoVid-19_susceptibility]
# file = /input_dir/corona_analysis/tracks/covid_hg38_1e6_susceptibility.bed
# height = 1
# title = CoVid-19 susceptibility 1e-6
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [Ellinghaus CoVid GWAS]
# file = /input_dir/corona_analysis/tracks/Ellinghaus_covid_gwas_hg38.bed
# height = 1
# title = Ellinghaus CoVid GWAS
# color = #e90ef4
# max_labels = 0
# file_type = bed
#
# [LINE elements]
# file = /input_dir/corona_analysis/annotations/hsflnil1_hg38_sorted.bed
# height = 1
# title = LINE retroelements
# fontsize = 10
# file_type = bed
#
# [Gencode genes]
# file = /input_dir/corona_analysis/annotations/gencode_v38.sorted.bed
# height = 4
# title = Gencode Genes
# fontsize = 8
# file_type = bed
# display = stacked
# labels_in_margin = false
# style = UCSC
# gene_rows = 10
# max_labels = 5000000
#
# #[ENCFF730XSB_HBEC_rnaseq_plus]
# #file = /input_dir/corona_analysis/tracks/NCFF322WTN_HBEC_rnaseq_plus.bw
# #title = RNA HBEC +
# #height = 2
# #color = #ef1a1a
# #min_value = 0
# #number_of_bins = 500
# #nans_to_zeros = True
# #summary_method = mean
# #show_data_range = true
# #file_type = bigwig
# #
# #[ENCFF730XSB_HBEC_rnaseq_minus]
# #file = /input_dir/corona_analysis/tracks/ENCFF730XSB_HBEC_rnaseq_minus.bw
# #title = RNA HBEC -
# #height = 2
# #color = #ef1a1a
# #min_value = 0
# #number_of_bins = 500
# #nans_to_zeros = True
# #summary_method = mean
# ##overlay_previous = share-y
# #orientation = inverted
# #show_data_range = true
# #file_type = bigwig
#
# [ENCFF121EOD_NHLF_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/ENCFF996XPQ_NHLF_rnaseq_plus_hg38.bw
# title = RNA NHLF +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [ENCFF121EOD_NHLF_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/ENCFF121EOD_NHLF_rnaseq_minus_hg38.bw
# title = RNA NHLF -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# #overlay_previous = share-y
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# #[Suztak eQTL arcs Tubules]
# #file = /input_dir/datavol/epigenetics_tracks/suzstak_eQTL_Tubules_all.arcs
# #title = Suztak eQTL arcs Tubules
# #color = #fc032c
# #links_type = arcs
# #line_style = solid
# #line_width = 1
# #height = 4
# #orientation = inverted

# %% [markdown]
# # All GWAS regions

# %%
# %%bash
#
# #Visualize all regions significantly correlated w/ CoVid susceptibility
# pyGenomeTracks --tracks regulatory_architecture_Mphage_fine.ini \
#     --BED "/input_dir/corona_analysis/tracks/covid_hg19_1e6_susceptibility_50kbMerged.bed" \
#     --outFileName "/input_dir/corona_analysis/out_viz/CoVid_susceptibility_mphage_finepadded.pdf"

# %%
# %%bash
# #Visualize all regions significantly correlated w/ CoVid susceptibility
# pyGenomeTracks --tracks regulatory_architecture_Mphage_broad.ini \
#     --BED "/input_dir/corona_analysis/tracks/covid_hg19_1e6_susceptibility_500kbMerged.bed" \
#     --outFileName "/input_dir/corona_analysis/out_viz/CoVid_susceptibility_broadpadded_mphage.pdf"

# %% [markdown]
# # CXCL16

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr17:4738322-4740133 \
#     --outFileName /input_dir/corona_analysis/out_viz/CXCL16_TSS_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr17:4732858-4741164 \
#     --outFileName /input_dir/corona_analysis/out_viz/CXCL16_gene_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr17:4403159-5108677 \
#     --outFileName /input_dir/corona_analysis/out_viz/CXCL16_TAD_hg38_lung.pdf

# %% [markdown]
# # IL6

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr7:22725324-22728538 \
#     --outFileName /input_dir/corona_analysis/out_viz/IL6_TSS_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr7:22724543-22743827 \
#     --outFileName /input_dir/corona_analysis/out_viz/IL6_gene_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr7:22491552-23559995 \
#     --outFileName /input_dir/corona_analysis/out_viz/IL6_TAD_hg38_lung.pdf
