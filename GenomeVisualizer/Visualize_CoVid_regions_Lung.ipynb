# %%
# %%writefile regulatory_architecture_lung_fine.ini
#
# [x-axis]
# where = top
#
# [H1 Primed CTCF loops]
# file = /input_dir/corona_analysis/tracks/primed_.7_origami_intra_hg38.arcs
# title = Cohesin Chia-PET
# color = #00a110
# links_type = arcs
# ylim = 300000
# compact_arcs_level = 2
# line_style = solid
# line_width = 1.5
# height = 5
#
# #[CTCF NN variants]
# #file =
# #title = Variants CTCF perturbing
# #height = 1
# #color = #e90ef4
# #max_labels = 0
# #labels = false
# #file_type = bed
#
# [ENCFF117BRM_CTCF_NHLF]
# file = /input_dir/corona_analysis/tracks/ENCFF117BRM_CTCF_NHLF.bw
# title = CTCF chip-seq
# height = 2
# color = #42f44e
# orientation = inverted
# min_value = 2
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [ENCFF782BOR_H3k4Me3_SAEC]
# file = /input_dir/corona_analysis/tracks/ENCFF782BOR_H3k4Me3_SAEC.bw
# title = H3k4Me3 fc Chip-seq
# height = 2
# color = #ffb42b
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [ENCFF637KNN_H3k27Ac_NHLF]
# file = /input_dir/corona_analysis/tracks/ENCFF637KNN_H3k27Ac_NHLF.bw
# title = H3k27Ac fc Chip-seq
# height = 2
# color = #42f4f4
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [ENCFF143LCY_H3k9Me3_NHLF]
# file = /input_dir/corona_analysis/tracks/ENCFF143LCY_H3k9Me3_NHLF.bw
# title = H3k9Me3 fc Chip-seq
# height = 2
# color = #a22eea
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [GSM1821904_SC_ATRX_K562]
# file = /input_dir/corona_analysis/tracks/GSM1821904_hg38-K562-ATRX_SC-enrichment_over_input.bw
# title = ATRX fc K562 chip-seq SC
# height = 2
# color = #9e0afa
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [GSM1821904_Abcam_ATRX_K562]
# file = /input_dir/corona_analysis/tracks/GSM1821905_hg38-K562-ATRX_Abcam-enrichment_over_input.bw
# title = ATRX fc K562 chip-seq Abcam
# height = 2
# color = #9e0afa
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [NHLF Chromatin state]
# file = /input_dir/corona_analysis/tracks/E128_15_coreMarks_dense.bed.gz
# fontsize = 8
# height = 1
# title = NHLF Chromatin State
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# [DNAse Peaks SAEC]
# file = /input_dir/corona_analysis/tracks/ENCFF827VFY_DNAse_SAEC.bed
# title = DNAse Peaks SAEC
# file_type = narrow_peak
# height = 1
# line_width = 1
# labels = false
# show_labels = false
# color = #1d6ae5
# display = collapsed
# fontsize = 10
#
# [ENCFF827VFY_DNAse_SAEC]
# file = /input_dir/corona_analysis/tracks/ENCFF827VFY_DNAse_SAEC.bw
# title = DNase sensitivity
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [Fetal_atlas_ATAC_vasc_endo]
# file = /input_dir/corona_analysis/tracks/lung_vascular_endothelial_cells_hg38.bw
# title = Agreggated scATAC-seq lung endothelial
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [Fetal_atlas_ATAC_bronch_alveo]
# file = /input_dir/corona_analysis/tracks/lung_bronchiolar_and_alveolar_epithelial_cells_hg38.bw
# title = Agreggated scATAC-seq broncheolar and epithelial
# height = 2
# color = #2a42f9
# min_value = 0
# orientation = inverted
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
#
# #rLoop stuff
#
#
#
# #G-quadruplex stuff
# [G-quadruplex 93T449]
# file = /input_dir/corona_analysis/tracks/GSE145535_RAW/GSM4320548_ChIPseq_IP_BG4_rep2_93T449_m1.ucsc.bigWig
# second_file = /input_dir/corona_analysis/tracks/GSE145535_RAW/GSM4320549_ChIPseq_Input_BG4_rep2_93T449_m1.ucsc.bigWig
# title = G-quadruplex Liposarcoma (93T449)
# operation = log2((1 + file) / (1 + second_file))
# height = 2
# color = #2a42f9
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [G-quadruplex HaCat]
# file = /input_dir/corona_analysis/tracks/GSE99205_common_HaCaT_G4_ChIP_peaks_RNase_treated_hg38.bed
# height = 1
# title = G-quadruplex HaCat peaks
# max_labels = 0
# color = #e90ef4
# file_type = bed
#
# [spacer]
# height = 1
#
# #[Mckay SCLC GWAS]
# #file = /input_dir/corona_analysis/tracks/mckay_2017_sclc_overall_hg38.bed
# #height = 1
# #title = Mckay SCLC GWAS
# #max_labels = 0
# #color = #e90ef4
# #file_type = bed
# #
# #[Wu SCLC GWAS]
# #file = /input_dir/corona_analysis/tracks/gwas_catalog_sclc_hg38.bed
# #height = 1
# #title = Wu SCLC GWAS
# #max_labels = 0
# #color = #e90ef4
# #file_type = bed
# #
# #[COPD GWAS]
# #file = /input_dir/corona_analysis/tracks/COPD_GWAS_hg38.bed
# #height = 1
# #title = COPD GWAS
# #max_labels = 0
# #color = #e90ef4
# #file_type = bed
# #
# #[IPF GWAS]
# #file = /input_dir/corona_analysis/tracks/ipf_gwas_hg38_allen_5e-8.bed
# #height = 1
# #title = IPF GWAS
# #max_labels = 0
# #color = #e90ef4
# #file_type = bed
# #
# #[CoVid-19_susceptibility]
# #file = /input_dir/corona_analysis/tracks/covid_hg38_1e6_susceptibility.bed
# #height = 1
# #title = CoVid-19 susceptibility 1e-6
# #max_labels = 0
# #color = #e90ef4
# #file_type = bed
# #
# #[Ellinghaus CoVid GWAS]
# #file = /input_dir/corona_analysis/tracks/Ellinghaus_covid_gwas_hg38.bed
# #height = 1
# #title = Ellinghaus CoVid GWAS
# #color = #e90ef4
# #max_labels = 0
# #file_type = bed
#
# [Knowles CF severity]
# file = /input_dir/corona_analysis/tracks/hg38_CF_severity_knowles_2015_GWAS.bed
# height = 1
# title = Knowles Cystic Fibrosis severity GWAS
# color = #e90ef4
# max_labels = 0
# file_type = bed
#
# [spacer]
# height = 1
#
# #[ClinVar kidney phenotype]
# #file = /input_dir/datavol/epigenetics_tracks/clinvar_kidney_variants_hg38.bed
# #height = 1
# #title = ClinVar w/ kidney phenotype
# #color = #e90ef4
# #max_labels = 0
# #file_type = bed
# #fontsize = 10
#
# [LINE elements]
# file = /input_dir/corona_analysis/annotations/hsflnil1_hg38_sorted.bed
# height = 1
# title = LINE retroelements
# fontsize = 10
# file_type = bed
# max_labels = 0
#
# [DTI sgRNAs]
# file = /input_dir/corona_analysis/tracks/DTI_plasmids/DTI_all_plasmids_hg38.bed
# height = 2
# title = DTI sgRNAs
# fontsize = 7
# file_type = bed
# max_labels = 1000
# color = #0dfff3
#
# [Gencode genes]
# file = /input_dir/corona_analysis/annotations/gencode_v38.sorted.bed
# height = 4
# title = Gencode Genes
# fontsize = 8
# file_type = bed
# display = stacked
# labels_in_margin = false
# style = UCSC
# gene_rows = 10
# max_labels = 5000000
#
# #[ENCFF730XSB_HBEC_rnaseq_plus]
# #file = /input_dir/corona_analysis/tracks/NCFF322WTN_HBEC_rnaseq_plus.bw
# #title = RNA HBEC +
# #height = 2
# #color = #ef1a1a
# #min_value = 0
# #number_of_bins = 500
# #nans_to_zeros = True
# #summary_method = mean
# #show_data_range = true
# #file_type = bigwig
# #
# #[ENCFF730XSB_HBEC_rnaseq_minus]
# #file = /input_dir/corona_analysis/tracks/ENCFF730XSB_HBEC_rnaseq_minus.bw
# #title = RNA HBEC -
# #height = 2
# #color = #ef1a1a
# #min_value = 0
# #number_of_bins = 500
# #nans_to_zeros = True
# #summary_method = mean
# ##overlay_previous = share-y
# #orientation = inverted
# #show_data_range = true
# #file_type = bigwig
#
# [ENCFF121EOD_NHLF_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/ENCFF996XPQ_NHLF_rnaseq_plus_hg38.bw
# title = RNA NHLF +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [ENCFF121EOD_NHLF_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/ENCFF121EOD_NHLF_rnaseq_minus_hg38.bw
# title = RNA NHLF -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# #overlay_previous = share-y
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [BALF_control_plus]
# file = /input_dir/corona_analysis/tracks/BALF_control_s1_rnaseq_minus_hg38.bw
# title = RNA BALF control +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [BALF_control_minus]
# file = /input_dir/corona_analysis/tracks/BALF_control_s1_rnaseq_plus_hg38.bw
# title = RNA BALF control -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# #overlay_previous = share-y
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# [spacer]
# height = 1
#
# [BALF_infected_plus]
# file = /input_dir/corona_analysis/tracks/BALF_corona_s1_rnaseq_minus_hg38.bw
# title = RNA BALF CoVid +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [BALF_infected_minus]
# file = /input_dir/corona_analysis/tracks/BALF_corona_s1_rnaseq_plus_hg38.bw
# title = RNA BALF CoVid -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# orientation = inverted
# #overlay_previous = share-y
# show_data_range = true
# file_type = bigwig

# %%
# %%writefile regulatory_architecture_lung_broad.ini
#
# [x-axis]
# where = top
#
# [IMR90 In-situ Hi-C]
# file=/input_dir/corona_analysis/tracks/4DNFIH7TH4MF_50kb_50000.cool
# title = IMR90 In-situ Hi-C
# colormap = coolwarm
# min_value = 1.2
# max_value = 8
# depth = 3000000
# transform = log
# show_masked_bins = False
# file_type = hic_matrix
# height = 10
#
# #[TAD Calls]
# #file = /input_dir/datavol/epigenetics_tracks/HEK293T_100kbTADs_domains.bed
# #file_type = domains
# #overlay_previous = share-y
# #fontsize = 8
# #line_width = 3
# #border_color = black
# #color = none
#
# [H1 Primed CTCF loops]
# file = /input_dir/corona_analysis/tracks/primed_.7_origami_intra_hg38.arcs
# title = Cohesin Chia-PET
# color = #00a110
# links_type = arcs
# line_style = solid
# orientation=inverted
# line_width = 1.5
# height = 5
#
# [ENCFF827VFY_DNAse_SAEC]
# file = /input_dir/corona_analysis/tracks/ENCFF827VFY_DNAse_SAEC.bw
# title = DNase sensitivity
# height = 3
# color = #2a42f9
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = True
# file_type = bigwig
#
# [GSM1821904_SC_ATRX_K562]
# file = /input_dir/corona_analysis/tracks/GSM1821904_hg38-K562-ATRX_SC-enrichment_over_input.bw
# title = ATRX fc K562 chip-seq SC
# height = 2
# color = #77a3bd
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [GSM1821904_Abcam_ATRX_K562]
# file = /input_dir/corona_analysis/tracks/GSM1821905_hg38-K562-ATRX_Abcam-enrichment_over_input.bw
# title = ATRX fc K562 chip-seq Abcam
# height = 2
# color = #77a3bd
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [NHLF Chromatin state]
# file = /input_dir/corona_analysis/tracks/E128_15_coreMarks_dense.bed.gz
# fontsize = 8
# height = 1
# title = NHLF Chromatin State
# display = color from bed rgb
# labels = false
# color = bed_rgb
# display = collapsed
#
# #[Mckay SCLC GWAS]
# #file = /input_dir/corona_analysis/tracks/mckay_2017_sclc_overall_hg38.bed
# #height = 1
# #title = Mckay SCLC GWAS
# #max_labels = 0
# #color = #e90ef4
# #file_type = bed
# #
# #[Wu SCLC GWAS]
# #file = /input_dir/corona_analysis/tracks/gwas_catalog_sclc_hg38.bed
# #height = 1
# #title = Wu SCLC GWAS
# #max_labels = 0
# #color = #e90ef4
# #file_type = bed
# #
# #[COPD GWAS]
# #file = /input_dir/corona_analysis/tracks/COPD_GWAS_hg38.bed
# #height = 1
# #title = COPD GWAS
# #max_labels = 0
# #color = #e90ef4
# #file_type = bed
# #
# #[IPF GWAS]
# #file = /input_dir/corona_analysis/tracks/ipf_gwas_hg38_allen_5e-8.bed
# #height = 1
# #title = IPF GWAS
# #max_labels = 0
# #color = #e90ef4
# #file_type = bed
# #
# #[CoVid-19_susceptibility]
# #file = /input_dir/corona_analysis/tracks/covid_hg38_1e6_susceptibility.bed
# #height = 1
# #title = CoVid-19 susceptibility 1e-6
# #max_labels = 0
# #color = #e90ef4
# #file_type = bed
# #
# #[Ellinghaus CoVid GWAS]
# #file = /input_dir/corona_analysis/tracks/Ellinghaus_covid_gwas_hg38.bed
# #height = 1
# #title = Ellinghaus CoVid GWAS
# #color = #e90ef4
# #max_labels = 0
# #file_type = bed
#
# [Knowles CF severity]
# file = /input_dir/corona_analysis/tracks/hg38_CF_severity_knowles_2015_GWAS.bed
# height = 1
# title = Knowles Cystic Fibrosis severity GWAS
# color = #e90ef4
# max_labels = 0
# file_type = bed
#
# [LINE elements]
# file = /input_dir/corona_analysis/annotations/hsflnil1_hg38_sorted.bed
# height = 1
# title = LINE retroelements
# fontsize = 10
# file_type = bed
# max_labels = 0
#
# [tRNA ScanSE]
# file = /input_dir/corona_analysis/annotations/hg38-tRNAs.bed
# height = 1
# title = tRNAs
# fontsize = 10
# file_type = bed
# max_labels = 0
#
# [DTI sgRNAs]
# file = /input_dir/corona_analysis/tracks/DTI_plasmids/DTI_all_plasmids_hg38.bed
# height = 2
# title = DTI sgRNAs
# fontsize = 7
# file_type = bed
# max_labels = 0
# color = #0dfff3
#
# [Gencode genes]
# file = /input_dir/corona_analysis/annotations/gencode_v38.sorted.bed
# height = 4
# title = Gencode Genes
# fontsize = 8
# file_type = bed
# display = stacked
# labels_in_margin = false
# style = UCSC
# gene_rows = 10
# max_labels = 5000000
#
# #[ENCFF730XSB_HBEC_rnaseq_plus]
# #file = /input_dir/corona_analysis/tracks/NCFF322WTN_HBEC_rnaseq_plus.bw
# #title = RNA HBEC +
# #height = 2
# #color = #ef1a1a
# #min_value = 0
# #number_of_bins = 500
# #nans_to_zeros = True
# #summary_method = mean
# #show_data_range = true
# #file_type = bigwig
# #
# #[ENCFF730XSB_HBEC_rnaseq_minus]
# #file = /input_dir/corona_analysis/tracks/ENCFF730XSB_HBEC_rnaseq_minus.bw
# #title = RNA HBEC -
# #height = 2
# #color = #ef1a1a
# #min_value = 0
# #number_of_bins = 500
# #nans_to_zeros = True
# #summary_method = mean
# ##overlay_previous = share-y
# #orientation = inverted
# #show_data_range = true
# #file_type = bigwig
#
# [ENCFF121EOD_NHLF_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/ENCFF996XPQ_NHLF_rnaseq_plus_hg38.bw
# title = RNA NHLF +
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# show_data_range = true
# file_type = bigwig
#
# [ENCFF121EOD_NHLF_rnaseq_minus]
# file = /input_dir/corona_analysis/tracks/ENCFF121EOD_NHLF_rnaseq_minus_hg38.bw
# title = RNA NHLF -
# height = 2
# color = #ef1a1a
# min_value = 0
# number_of_bins = 500
# nans_to_zeros = True
# summary_method = mean
# #overlay_previous = share-y
# orientation = inverted
# show_data_range = true
# file_type = bigwig
#
# #[eQTL arcs]
# #file = /input_dir/datavol/epigenetics_tracks/eQTL_links.arcs
# #title = eQTL arcs
# #color = #fc032c
# #links_type = arcs
# #line_style = solid
# #line_width = 1
# #height = 4
# #orientation = inverted

# %% [markdown]
# # All GWAS regions

# %%
# %%bash
#
# #Visualize all regions significantly correlated w/ CoVid susceptibility
# pyGenomeTracks --tracks regulatory_architecture_Mphage_fine.ini \
#     --BED "/input_dir/corona_analysis/tracks/covid_hg38_1e6_susceptibility_50kbMerged.bed" \
#     --outFileName "/input_dir/corona_analysis/out_viz/CoVid_susceptibility_mphage_finepadded.pdf"

# %%
# %%bash
# #Visualize all regions significantly correlated w/ CoVid susceptibility
# pyGenomeTracks --tracks regulatory_architecture_Mphage_broad.ini \
#     --BED "/input_dir/corona_analysis/tracks/covid_hg38_1e6_susceptibility_500kbMerged.bed" \
#     --outFileName "/input_dir/corona_analysis/out_viz/CoVid_susceptibility_broadpadded_mphage.pdf"

# %% [markdown]
# # CXCL16

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr17:4738322-4740133 \
#     --outFileName /input_dir/corona_analysis/out_viz/CXCL16_TSS_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr17:4732858-4741164 \
#     --outFileName /input_dir/corona_analysis/out_viz/CXCL16_gene_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr17:4403159-5108677 \
#     --outFileName /input_dir/corona_analysis/out_viz/CXCL16_TAD_hg38_lung.pdf

# %% [markdown]
# # HLA region

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr6:25550790-33630955 \
#     --outFileName /input_dir/corona_analysis/out_viz/HLA_TAD_hg38_lung.pdf

# %% [markdown]
# # Histone Clusters
#
# chr1:143320028-149902294 -- Histone cluster w/ bunch of tRNAs
#
# chr1:161419636-161481412 -- tRNA cluster w/ viral cassette like distribution
#
# chr1:228420413-228657700 -- Histone cluster w/ 5s rRNA
#
# chr6:25865848-29288735 -- Histone cluster w/ HLA

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr1:143320028-149902294 \
#     --outFileName /input_dir/corona_analysis/out_viz/Histone_cluster1_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr1:161419636-161481412 \
#     --outFileName /input_dir/corona_analysis/out_viz/Histone_cluster2_hg38.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr1:228420413-228657700 \
#     --outFileName /input_dir/corona_analysis/out_viz/Histone_cluster3_hg38.pdf

# %%
# %%bash
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr6:25865848-29288735 \
#     --outFileName /input_dir/corona_analysis/out_viz/Histone_cluster4_hg38.pdf

# %% [markdown]
# # IL6

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr7:22725324-22728538 \
#     --outFileName /input_dir/corona_analysis/out_viz/IL6_TSS_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr7:22724543-22743827 \
#     --outFileName /input_dir/corona_analysis/out_viz/IL6_gene_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr7:22491552-23559995 \
#     --outFileName /input_dir/corona_analysis/out_viz/IL6_TAD_hg38_lung.pdf

# %% [markdown]
# # GSTCD
#
# * chr4:105662395-105894379 # fine hg38
# * chr4:105698396-105727514 # tss hg38
# * chr4:105068288-106695910 # broad hg38

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr4:105698396-105727514 \
#     --outFileName /input_dir/corona_analysis/out_viz/GSTCD_TSS_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr4:105662395-105894379 \
#     --outFileName /input_dir/corona_analysis/out_viz/GSTCD_gene_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr4:104211178-106300000 \
#     --outFileName /input_dir/corona_analysis/out_viz/GSTCD_broad_hg38_lung.pdf

# %% [markdown]
# # Small Cell Lung Carcinoma regions
#
# * MYC
# * MYCN
# * TP53
# * TP73
# * RB1 (?)

# %%
# %%bash
#
# ## Do visualization of fine regions which are present in both datasets
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --BED /input_dir/corona_analysis/tracks/mckay_merge_hg38_sclc.bed \
#     --outFileName /input_dir/corona_analysis/out_viz/SCLC_fine_hg38_lung.pdf

# %%
# %%bash
#
# ## Do visualization of wide regions which are present in both datasets
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --BED /input_dir/corona_analysis/tracks/mckay_merge_wide_hg38_sclc.bed \
#     --outFileName /input_dir/corona_analysis/out_viz/SCLC_wide_hg38_lung.pdf

# %% [markdown]
# ## Myc

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr8:127735065-127736548 \
#     --outFileName /input_dir/corona_analysis/out_viz/MYC_TSS_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr8:127734661-127742944 \
#     --outFileName /input_dir/corona_analysis/out_viz/MYC_gene_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr8:127724511-127896163 \
#     --outFileName /input_dir/corona_analysis/out_viz/MYC_gene_broad_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr8:126662627-129870643 \
#     --outFileName /input_dir/corona_analysis/out_viz/MYC_broad_hg38_lung.pdf

# %% [markdown]
# ## TP73

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr1:3685628-3698979 \
#     --outFileName /input_dir/corona_analysis/out_viz/TP73_TSS_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr1:3649699-3749625 \
#     --outFileName /input_dir/corona_analysis/out_viz/TP73_gene_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr1:2958490-4256820 \
#     --outFileName /input_dir/corona_analysis/out_viz/TP73_broad_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr16:53643753-55367972 \
#     --outFileName /input_dir/corona_analysis/out_viz/IRX3_FTO_broad_hg38_lung.pdf

# %% [markdown]
# ## KRAS

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr12:25249898-25251819 \
#     --outFileName /input_dir/corona_analysis/out_viz/KRAS_TSS_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr12:25202758-25253558 \
#     --outFileName /input_dir/corona_analysis/out_viz/KRAS_gene_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr12:24833044-25624598 \
#     --outFileName /input_dir/corona_analysis/out_viz/KRAS_broad_hg38_lung.pdf

# %% [markdown]
# # CFTR -- Cystic fibrosis
#
# Couple of zooms, focusing around L1 elements close to CFTR and some GWAS regions
#
# * CFTR TSS = chr7:117479191-117480641
# * CFTR gene = chr7:117461354-117672910
# * CFTR IN = chr7:117018827-117937675
# * CFTR TAD = chr7:116374746-118211808
#
# * MUC4 gene = chr3:195719696-195839286
# * AGTR2 gene = chrX:116038958-116308684

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chrX:116038958-116308684 \
#     --outFileName /input_dir/corona_analysis/out_viz/AGTR2_gene_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr3:195719696-195839286 \
#     --outFileName /input_dir/corona_analysis/out_viz/MUC4_gene_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr7:117478495-117482027 \
#     --outFileName /input_dir/corona_analysis/out_viz/CFTR_TSS_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_fine.ini \
#     --region chr7:117461354-117672910 \
#     --outFileName /input_dir/corona_analysis/out_viz/CFTR_gene_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr7:117018827-117937675 \
#     --outFileName /input_dir/corona_analysis/out_viz/CFTR_IN_hg38_lung.pdf

# %%
# %%bash
#
# pyGenomeTracks --tracks regulatory_architecture_lung_broad.ini \
#     --region chr7:116374746-118211808 \
#     --outFileName /input_dir/corona_analysis/out_viz/CFTR_TAD_hg38_lung.pdf
