# %% [markdown]
# # Code to get lung, heart, kidney control uninfected scRNA-seq

# %% [markdown]
# ## Really good kidney dataset from:
#
# Single cell transcriptomics identifies focal segmental glomerulosclerosis remission endothelial biomarker
#
# https://insight.jci.org/articles/view/133267
#
# SRA: PRJNA591621
#
# No raw data provided

# %% [markdown]
# # Good scRNA-seq data from 3 donors
#
# ["Single-cell RNA sequencing of human kidney"](https://www.nature.com/articles/s41597-019-0351-8)
#
# SRR10377488-SRR10377490 10x Genomics v2 chemistry
#
# First read only in SRA file because of weird .bam encoding, can download original bam and flip to fastq using bamtofastq 10x genomics utility, then concatenate and maybe feed to salmon?

# %% [markdown]
# ## Try getting data from [Construction of a human cell landscape at single-cell level](https://www.nature.com/articles/s41586-020-2157-4)
# Large compendium of different tissues all in scRNA-seq, done using the Microwell-seq methodology worth incorporating it seems?
#
# SRA website: https://trace.ncbi.nlm.nih.gov/Traces/sra/?study=SRP214806
#
# ## Kidney
# * SRR9887772 - Sample_1_1 - Adult kidney
# * SRR9887773 - Sample_1_2 - Adult kidney
# * SRR9887774 - Sample_2_1 - Adult kidney
# * SRR9887775 - Sample_3_1 - Adult kidney
#
# ## Lung
# * SRR9887736 - Sample_3_1 - Adult lung
# * SRR9887737 - Sample_2_1 - Adult lung
# * SRR9887738 - Sample_3_3 - Adult lung
# * SRR9887739 - Sample_3_2 - Adult lung
#
# ## Heart only 2 adult
# * SRR9843423 - Sample_1_1 - Adult heart
# * SRR9843424 - Sample_2_1 - Adult heart

# %% [markdown]
# # Third source
#
# [A single-nucleus RNA-sequencing pipeline to decipher the molecular anatomy and pathophysiology of human kidneys](https://www.nature.com/articles/s41467-019-10861-2)
#
# snDrop-seq Jain
#
# Run	Experiment
# * SRR8114240 - SRX4940606
# * SRR8114241 - SRX4940607
# * SRR8114242 - SRX4940608
# * SRR8114243 - SRX4940608
# * SRR8114244 - SRX4940609
# * SRR8114247 - SRX4940610
# * SRR8114248 - SRX4940611
# * SRR8114249 - SRX4940611
# * SRR8114250 - SRX4940612
# * SRR8114251 - SRX4940612
# * SRR8114252 - SRX4940613
# * SRR8114253 - SRX4940613
# * SRR8114254 - SRX4940614
# * SRR8114255 - SRX4940614
# * SRR8114256 - SRX4940615
# * SRR8114257 - SRX4940615
# * SRR8114258 - SRX4940616
# * SRR8114259 - SRX4940616
# * SRR8114260 - SRX4940617
# * SRR8114261 - SRX4940617
# * SRR8114262 - SRX4940618
# * SRR8114263 - SRX4940618
# * SRR8114264 - SRX4940619
# * SRR8114265 - SRX4940619
# * SRR8114266 - SRX4940620
# * SRR8114267 - SRX4940620
# * SRR8114268 - SRX4940621
# * SRR8114269 - SRX4940621
# * SRR8114271 - SRX4940622
# * SRR8114272 - SRX4940623
# * SRR8114273 - SRX4940623
# * SRR8114276 - SRX4940625
# * SRR8114277 - SRX4940625
# * SRR8114278 - SRX4940626
# * SRR8114279 - SRX4940626
# * SRR8114280 - SRX4940627
# * SRR8114281 - SRX4940627
# * SRR8114282 - SRX4940628
# * SRR8114283 - SRX4940628
# * SRR8114284 - SRX4940629
# * SRR8114285 - SRX4940629
# * SRR8114286 - SRX4940630
# * SRR8114288 - SRX4940631
# * SRR8114289 - SRX4940631
# * SRR8114290 - SRX4940632
# * SRR8114291 - SRX4940632
# * SRR8114292 - SRX4940633
# * SRR8114294 - SRX4940634
# * SRR8114295 - SRX4940634
# * SRR8114296 - SRX4940635
# * SRR8114297 - SRX4940635
# * SRR8114298 - SRX4940636
# * SRR8114299 - SRX4940636
# * SRR8114300 - SRX4940637
# * SRR8114301 - SRX4940637
# * SRR8114302 - SRX4940638
# * SRR8114303 - SRX4940638
# * SRR8114305 - SRX4940639
# * SRR8114307 - SRX4940640
# * SRR8114308 - SRX4940641
# * SRR8114309 - SRX4940641
# * SRR8114311 - SRX4940642
# * SRR8114312 - SRX4940643
# * SRR8114314 - SRX4940644
# * SRR8114315 - SRX4940644
# * SRR8114316 - SRX4940645
# * SRR8114317 - SRX4940645
# * SRR8114318 - SRX4940646
# * SRR8114319 - SRX4940646
# * SRR8114320 - SRX4940647
# * SRR8114321 - SRX4940647
# * SRR8114322 - SRX4940648
# * SRR8114323 - SRX4940648
# * SRR8114324 - SRX4940649
# * SRR8114325 - SRX4940649
# * SRR8114326 - SRX4940650
# * SRR8114327 - SRX4940650
# * SRR8114328 - SRX4940651
# * SRR8114329 - SRX4940651
# * SRR8114331 - SRX4940652
# * SRR8114246 - SRX4940610
# * SRR8114270 - SRX4940622
# * SRR8114274 - SRX4940624
# * SRR8114275 - SRX4940624
# * SRR8114287 - SRX4940630
# * SRR8114304 - SRX4940639
# * SRR8114306 - SRX4940640
# * SRR8114310 - SRX4940642
# * SRR8114313 - SRX4940643
# * SRR8114330 - SRX4940652
# * SRR8114293 - SRX4940633
# * SRR8114245 - SRX4940609

# %%
# %%bash
#
# #Prefetch normal kidney samples
# prefetch -o /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887772.sra SRR9887772
# prefetch -o /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887773.sra SRR9887773
# prefetch -o /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887774.sra SRR9887774
# prefetch -o /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887775.sra SRR9887775
#
# #Prefetch normal lung samples
# prefetch -o /input_dir/corona_analysis/input_reads/lung_scRNA_control/SRR9887736.sra SRR9887736
# prefetch -o /input_dir/corona_analysis/input_reads/lung_scRNA_control/SRR9887737.sra SRR9887737
# prefetch -o /input_dir/corona_analysis/input_reads/lung_scRNA_control/SRR9887738.sra SRR9887738
# prefetch -o /input_dir/corona_analysis/input_reads/lung_scRNA_control/SRR9887739.sra SRR9887739
#
# #Prefetch normal heart samples
# prefetch -o /input_dir/corona_analysis/input_reads/heart_scRNA_control/SRR9843423.sra SRR9843423
# prefetch -o /input_dir/corona_analysis/input_reads/heart_scRNA_control/SRR9843424.sra SRR9843424

# %%
# %%bash
#
# #Prefetch normal kidney samples
# prefetch -o /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377488.sra SRR10377488
# prefetch -o /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377489.sra SRR10377489
# prefetch -o /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377490.sra SRR10377490

# %%
# %%bash
#
# #Prefetch normal kidney samples https://www.nature.com/articles/s41467-019-10861-2
# prefetch -o /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR8114241.sra SRR8114241

# %%
# %%bash
# #Kidney
# parallel-fastq-dump -t 12 --tmpdir /input_dir/corona_analysis/temp/ \
#     -s /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR8114241.sra \
#     --dumpbase --clip --skip-technical --readids  \
#     --read-filter pass --split-files --origfmt \
#     --outdir /input_dir/corona_analysis/input_reads/kidney_scRNA_control

# %%
#More kidney samples
parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
    -s /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377488.sra \
    --dumpbase --clip --readids \
    --read-filter pass --split-files --origfmt \
    --outdir /input_dir/corona_analysis/input_reads/kidney_scRNA_control
parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
    -s /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377489.sra \
    --dumpbase --clip --readids \
    --read-filter pass --split-files --origfmt \
    --outdir /input_dir/corona_analysis/input_reads/kidney_scRNA_control
parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
    -s /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377490.sra \
    --dumpbase --clip --readids \
    --read-filter pass --split-files --origfmt \
    --outdir /input_dir/corona_analysis/input_reads/kidney_scRNA_control

# %%
# %%bash
#
# #Flip SRA to fastq no gzip
# #Kidney
# parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
#     -s /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887772.sra \
#     --dumpbase --clip --readids \
#     --read-filter pass --split-files --origfmt \
#     --outdir /input_dir/corona_analysis/input_reads/kidney_scRNA_control
# parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
#     -s /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887773.sra \
#     --dumpbase --clip --readids \
#     --read-filter pass --split-files --origfmt \
#     --outdir /input_dir/corona_analysis/input_reads/kidney_scRNA_control
# parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
#     -s /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887774.sra \
#     --dumpbase --clip --readids \
#     --read-filter pass --split-files --origfmt \
#     --outdir /input_dir/corona_analysis/input_reads/kidney_scRNA_control
# parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
#     -s /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887775.sra \
#     --dumpbase --clip --readids \
#     --read-filter pass --split-files --origfmt \
#     --outdir /input_dir/corona_analysis/input_reads/kidney_scRNA_control
# #Lung
# parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
#     -s /input_dir/corona_analysis/input_reads/lung_scRNA_control/SRR9887736.sra \
#     --dumpbase --clip --readids \
#     --read-filter pass --split-files --origfmt \
#     --outdir /input_dir/corona_analysis/input_reads/lung_scRNA_control
# parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
#     -s /input_dir/corona_analysis/input_reads/lung_scRNA_control/SRR9887737.sra \
#     --dumpbase --clip --readids \
#     --read-filter pass --split-files --origfmt \
#     --outdir /input_dir/corona_analysis/input_reads/lung_scRNA_control
# parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
#     -s /input_dir/corona_analysis/input_reads/lung_scRNA_control/SRR9887738.sra \
#     --dumpbase --clip --readids \
#     --read-filter pass --split-files --origfmt \
#     --outdir /input_dir/corona_analysis/input_reads/lung_scRNA_control
# parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
#     -s /input_dir/corona_analysis/input_reads/lung_scRNA_control/SRR9887739.sra \
#     --dumpbase --clip --readids \
#     --read-filter pass --split-files --origfmt \
#     --outdir /input_dir/corona_analysis/input_reads/lung_scRNA_control
# #Heart
# parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
#     -s /input_dir/corona_analysis/input_reads/heart_scRNA_control/SRR9843423.sra \
#     --dumpbase --clip --readids \
#     --read-filter pass --split-files --origfmt \
#     --outdir /input_dir/corona_analysis/input_reads/heart_scRNA_control
# parallel-fastq-dump -t 8 --tmpdir /input_dir/corona_analysis/temp/ \
#     -s /input_dir/corona_analysis/input_reads/heart_scRNA_control/SRR9843424.sra \
#     --dumpbase --clip --readids \
#     --read-filter pass --split-files --origfmt \
#     --outdir /input_dir/corona_analysis/input_reads/heart_scRNA_control

# %%
# %%bash
#
# #Use UMI tools to pull out barcode whitelist
# umi_tools whitelist --bc-pattern CCCCCCXXXXXXXXXXXXXXXCCCCCCXXXXXXXXXXXXXXXCCCCCCNNNNNN \
#     -I SRR9887762_pass_1.fastq.gz \
#     -S test_barcode.txt --subset-reads 15000000

# %%
#Filter out adapters that don't have at least 9 of 10 Ts at the end

~/.local/bin/cutadapt -j 10 -a TTTTTTTTT$ -m 21 -e 0.6 --discard-untrimmed \
    -o SRR8114241_filt_1.fastq \
    -p SRR8114241_filt_2.fastq \
     SRR8114241_pass_1.fastq SRR8114241_pass_2.fastq

# %%
# %%bash
#
# #Get original uploaded .bam files and flip to fastq using cellranger software because SRA is dumb about scRNA-seq and scrubs the goddamn index read
# curl -s -L https://sra-pub-src-2.s3.amazonaws.com/SRR10377488/possorted_genome_bam1.bam.1 > \
#     /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377488.bam
# curl -s -L https://sra-pub-src-2.s3.amazonaws.com/SRR10377489/possorted_genome_bam2.bam.1 > \
#     /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377489.bam
# curl -s -L https://sra-pub-src-2.s3.amazonaws.com/SRR10377490/possorted_genome_bam3.bam.1 > \
#     /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377490.bam

# %%
# %%bash
# cd /input_dir/corona_analysis/input_reads/kidney_scRNA_control/
# #Get app to flip bams from cellranger etc to fastq
# curl -s -L http://cf.10xgenomics.com/misc/bamtofastq-1.2.0 > bamtofastq
# chmod 755 bamtofastq

# %%
# %%bash
#
# #Flip downloaded original cell ranger output to fq to rerun analysis
# ./bamtofastq --nthreads 12 SRR10377488.bam /input_dir/corona_analysis/input_reads/kidney_scRNA_control/s1
# ./bamtofastq --nthreads 12 SRR10377489.bam /input_dir/corona_analysis/input_reads/kidney_scRNA_control/s2
# ./bamtofastq --nthreads 12 SRR10377490.bam /input_dir/corona_analysis/input_reads/kidney_scRNA_control/s3

# %%
# %%bash
#
# #Concatenate read files together for index and read
# cd /input_dir/corona_analysis/input_reads/kidney_scRNA_control/s1/kidney1_result_0_1_H7K5MDMXX
# cat *I* > /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377488_I.fq.gz
# cat *R* > /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377488_R.fq.gz
#
# cd /input_dir/corona_analysis/input_reads/kidney_scRNA_control/s2/kidney2_result_0_1_HMKGYCCXY
# cat *I* > /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377489_I.fq.gz
# cat *R* > /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377489_R.fq.gz
#
# cd /input_dir/corona_analysis/input_reads/kidney_scRNA_control/s3/kidney3_result_0_1_HMKGYCCX
# cat *I* > /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377490_I.fq.gz
# cat *R* > /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR10377490_R.fq.gz

# %%
#Filter input RNA-seq reads from control scRNA kidney from donors
#Ctrl1
fastp -p 8 -i /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887762_pass_1.fastq.gz \
      -I /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887762_pass_2.fastq.gz \
      -o /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887762_1_filt.fq.gz \
      -O /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887762_2_filt.fq.gz \
      -h /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887762_fastp.html \
      -j /input_dir/corona_analysis/input_reads/kidney_scRNA_control/SRR9887762_fastp.json \
      --umi --umi_loc read1 --umi_len 54

# %% [markdown]
# # K-Mer based workflow for scRNA-seq
#
# * Compile needed annotation files
# * Build needed references
# * Quantify against reference
#
# ## Get and massage annotation files needed for Salmon human
#
# Using all Ensembl-99 as ground truth

# %%
# %%bash
#
# cd /input_dir/corona_analysis/annotations/human/
#
# #Get hard masked hg38 genome and filter for only canonical chromosomes
# curl -s -L ftp://ftp.ensembl.org/pub/release-99/fasta/homo_sapiens/dna/Homo_sapiens.GRCh38.dna_rm.primary_assembly.fa.gz > \
#     /input_dir/corona_analysis/annotations/human/Homo_sapiens.GRCh38.dna_rm.primary_assembly.fa.gz
# gunzip Homo_sapiens.GRCh38.dna_rm.primary_assembly.fa.gz
# #Toss everything except canonical chromosomes
# awk "/^>/ {n++} n>25 {exit} {print}" /input_dir/corona_analysis/annotations/human/Homo_sapiens.GRCh38.dna_rm.primary_assembly.fa > GRCh38_filt_dna_rm.fa
# #Get list of decoy sequences for salmon
# grep "^>" /input_dir/corona_analysis/annotations/human/GRCh38_filt_dna_rm.fa | cut -d " " -f 1 > decoys.txt
# sed -i.bak -e 's/>//g' decoys.txt

# %%
# %%bash
#
# #Get cDNA of transcripts for hg38
# wget ftp://ftp.ensembl.org/pub/release-99/fasta/homo_sapiens/cdna/Homo_sapiens.GRCh38.cdna.all.fa.gz
# gunzip Homo_sapiens.GRCh38.cdna.all.fa.gz
#
# #Filter the transcripts for only those in STAR
# cut -f 1 /input_dir/corona_analysis/annotations/human/STAR_ix/transcriptInfo.tab > in_enst_names.txt
# awk '{ if ((NR>1)&&($0~/^>/)) { printf("\n%s", $0); } else if (NR==1) { printf("%s", $0); } else { printf("\t%s", $0); } }' \
#     Homo_sapiens.GRCh38.cdna.all.fa \
#     | grep -Ff in_enst_names.txt - \
#     | tr "\t" "\n" > Hg38_cdna_filt.fa
#
# # coding_genes_hgnc.txt = list of all HGNC protein coding symbols
# #Filter the transcripts to ONLY protein coding
# awk '{ if ((NR>1)&&($0~/^>/)) { printf("\n%s", $0); } else if (NR==1) { printf("%s", $0); } else { printf("\t%s", $0); } }' \
#     Hg38_cdna_filt.fa \
#     | grep -Ff coding_genes_hgnc.txt - \
#     | tr "\t" "\n" > Hg38_cdna_coding_filt.fa

# %%
# %%bash
#
# cd /input_dir/corona_analysis/annotations/human/
#
# #Get ensembl gtf file
# curl -s -L ftp://ftp.ensembl.org/pub/release-99/gtf/homo_sapiens/Homo_sapiens.GRCh38.99.gtf.gz > \
#     /input_dir/corona_analysis/annotations/human/Homo_sapiens.GRCh38.99.gtf.gz
# gunzip /input_dir/corona_analysis/annotations/human/Homo_sapiens.GRCh38.99.gtf.gz

# %% [markdown]
# ### Get rRNA from
#
# https://www.genenames.org/data/genegroup/#!/group/848
#
# Flip to ENST using Biomart and feed into rRNA_ensembl.txt to get rRNA_ensembl_cdna.fa

# %%
# %%bash
# #Make gentrome for Salmon
# mkdir /input_dir/corona_analysis/annotations/human/salmon_ann
# cd /input_dir/corona_analysis/annotations/human/salmon_ann
# cat /input_dir/corona_analysis/annotations/human/Hg38_cdna_coding_filt.fa \
#     /input_dir/corona_analysis/annotations/human/rRNA_ensembl_cdna.fa \
#     /input_dir/corona_analysis/annotations/human/GRCh38_filt_dna_rm.fa \
#     > gentrome_hg38_filt.fa
#
# #Full cdna file: Homo_sapiens.GRCh38.cdna.all.fa
# #Filtered cdna file: Hg38_cdna_coding_filt.fa

# %%
# %%bash
# #Reduce ram used w/ sparse
# salmon index --sparse -t gentrome_hg38_filt.fa -d ../decoys.txt -p 10 -i salmon_hg38_index

# %%
gtf_parse = "/input_dir/corona_analysis/annotations/human/Homo_sapiens.GRCh38.99.gtf"
mt_tran_out = "/input_dir/corona_analysis/annotations/human/gencode_mt.txt"
out_tran_map = "/input_dir/corona_analysis/annotations/human/salmon_grch38_gencode_tran2gene.txt"

tran_gene_dict = dict()
tran_name_dict = dict()

with open(gtf_parse, "r") as gene_in:
    with open(mt_tran_out,"w") as mito_out:
        for line in gene_in:
            if line.startswith("#"):
                continue
            else:
                arr = line.strip().split("\t")
                if (arr[2] == "transcript"):
                    tmp_arr = arr[-1].strip(';').strip().split(";")
                    tmp_arr = tmp_arr[:-1]
                    arr_tran = [feature.strip().split(" ") for feature in tmp_arr]
                    cur_tran_dict = {key: value for (key, value) in arr_tran}
                    tran_gene_dict[cur_tran_dict["transcript_id"]+"."+cur_tran_dict["transcript_version"]] = cur_tran_dict["gene_id"]+"."+cur_tran_dict["gene_version"]
                    tran_name_dict[cur_tran_dict["transcript_id"]+"."+cur_tran_dict["transcript_version"]] = cur_tran_dict["gene_name"]

                    if arr[0] == "MT":
                        mito_out.write(cur_tran_dict["transcript_id"].strip("\"")+"."+cur_tran_dict["transcript_version"].strip("\"") + "\n")
                        
                        

with open(out_tran_map, "w") as kal_tran:
    for tran in tran_gene_dict.keys():
        out_line = tran.replace("\"","") + "\t" + tran_gene_dict[tran].replace("\"","") + "\n"
        kal_tran.write(out_line)

# %%
# %%bash
#
# #Add rRNA to transcript2gene map
# grep ">" /input_dir/corona_analysis/annotations/human/rRNA_ensembl_cdna.fa | \
#     awk -F '|' '{print $4 "\t" $2 }' >> /input_dir/corona_analysis/annotations/human/salmon_grch38_gencode_tran2gene.txt

# %%
# %%bash
#
# #Get transcript IDs of rRNA w/ version ID
# grep ">" /input_dir/corona_analysis/annotations/human/rRNA_ensembl_cdna.fa | cut -f 1 -d '|' \
#     | sed 's/>//' > \
#     /input_dir/corona_analysis/annotations/human/rRNA_ensembl.txt

# %%
# %%bash
#
# #Map kidney scRNA reads using alevin
# cd /input_dir/corona_analysis/input_reads/kidney_scRNA_control

# %%
#Attempt doing a sample from landscape
salmon alevin -l ISR \
              -1 SRR9887762_pass_1.fastq \
              -2 SRR9887762_pass_2.fastq \
              --dropseq \
              -i /input_dir/corona_analysis/annotations/human/salmon/salmon_hg38_index \
              -p 3 \
              --mrna /input_dir/corona_analysis/annotations/human/gencode_mt.txt \
              --rrna /input_dir/corona_analysis/annotations/human/rRNA_ensembl.txt \
              -o /input_dir/corona_analysis/alignment_out/kidney_scRNA_control/salmon_out_s1 \
              --tgMap /input_dir/corona_analysis/annotations/human/salmon_grch38_gencode_tran2gene.txt

# %%
#Attempt doing a sample from landscape
salmon alevin -l ISR \
              -1 SRR9887772_pass_1.fastq \
              -2 SRR9887772_pass_2.fastq \
              --dropseq \
              -i /input_dir/corona_analysis/annotations/human/salmon_ann/salmon_hg38_index \
              -p 10 \
              --mrna /input_dir/corona_analysis/annotations/human/gencode_mt.txt \
              --rrna /input_dir/corona_analysis/annotations/human/rRNA_ensembl.txt \
              -o /input_dir/corona_analysis/alignment_out/kidney_scRNA_control/salmon_out_landscape_s1 \
              --tgMap /input_dir/corona_analysis/annotations/human/salmon_grch38_gencode_tran2gene.txt

salmon alevin -l ISR \
              -1 SRR9887773_pass_1.fastq \
              -2 SRR9887773_pass_2.fastq \
              --dropseq \
              -i /input_dir/corona_analysis/annotations/human/salmon_ann/salmon_hg38_index \
              -p 10 \
              --mrna /input_dir/corona_analysis/annotations/human/gencode_mt.txt \
              --rrna /input_dir/corona_analysis/annotations/human/rRNA_ensembl.txt \
              -o /input_dir/corona_analysis/alignment_out/kidney_scRNA_control/salmon_out_landscape_s2 \
              --tgMap /input_dir/corona_analysis/annotations/human/salmon_grch38_gencode_tran2gene.txt

# %%
# %%bash
#
# ##Figure out whitelisting issue
# salmon alevin -l ISR \
#               -1 SRR8114241_filt_1.fastq \
#               -2 SRR8114241_filt_2.fastq \
#               --dropseq \
#               -i /input_dir/corona_analysis/annotations/human/salmon_ann/salmon_hg38_index \
#               -p 10 --noQuant --dumpFeature \
#               -o /input_dir/corona_analysis/alignment_out/kidney_scRNA_control/salmon_out_jain_s1 \
#               --tgMap /input_dir/corona_analysis/annotations/human/salmon_grch38_gencode_tran2gene.txt
#
#
#
# #Run for snDrop-Seq jain one kidney using hard 2000 expectCells cutoff for CB
# salmon alevin -l ISR \
#               -1 SRR8114241_filt_1.fastq \
#               -2 SRR8114241_filt_2.fastq \
#               --dropseq --forceCells 58478 \
#               -i /input_dir/corona_analysis/annotations/human/salmon_ann/salmon_hg38_index \
#               -p 14 --dumpFeature \
#               -o /input_dir/corona_analysis/alignment_out/kidney_scRNA_control/salmon_out_jain_s1 \
#               --tgMap /input_dir/corona_analysis/annotations/human/salmon_grch38_gencode_tran2gene.txt
#
#
# # manual barcode info
# # --barcodeLength 12 --umiLength 8 --end 3
#
# # Mitochondrial and ribosomal RNA estimation of CB whitelisting
# --mrna /input_dir/corona_analysis/annotations/human/gencode_mt.txt \
# --rrna /input_dir/corona_analysis/annotations/human/rRNA_ensembl.txt

# %%
# %%bash
#
# #Map lung scRNA reads using alevin
# cd /input_dir/corona_analysis/input_reads/lung_scRNA_control
#
# salmon alevin -l ISR \
#               -1 SRR9887739_pass_1.fastq \
#               -2 SRR9887739_pass_2.fastq \
#               --dropseq \
#               -i /input_dir/corona_analysis/annotations/human/salmon/salmon_hg38_index \
#               -p 8 \
#               --mrna /input_dir/corona_analysis/annotations/human/gencode_mt.txt \
#               --rrna /input_dir/corona_analysis/annotations/human/rRNA_ensembl.txt \
#               -o /input_dir/corona_analysis/alignment_out/lung_scRNA_control/salmon_out_1s \
#               --tgMap /input_dir/corona_analysis/annotations/human/salmon_grch38_gencode_tran2gene.txt

# %%
 # %%bash 
    
#Run for snDrop-Seq jain one kidney using hard 2000 expectCells cutoff for CB
salmon alevin -l ISR \
              -1 SRR10377488_I.fq.gz \
              -2 SRR10377488_R.fq.gz \
              --chromium \
              --mrna /input_dir/corona_analysis/annotations/human/gencode_mt.txt \
              --rrna /input_dir/corona_analysis/annotations/human/rRNA_ensembl.txt \
              -i /input_dir/corona_analysis/annotations/human/salmon_ann/salmon_hg38_index \
              -p 14 --dumpFeature \
              -o /input_dir/corona_analysis/alignment_out/kidney_scRNA_control/salmon_out_mo_s1 \
              --tgMap /input_dir/corona_analysis/annotations/human/salmon_grch38_gencode_tran2gene.txt


 # %%bash 
    
#Run for snDrop-Seq jain one kidney using hard 2000 expectCells cutoff for CB
salmon alevin -l ISR \
              -1 t1.fq \
              -2 t2.fq \
              --chromium \
              --mrna /input_dir/corona_analysis/annotations/human/gencode_mt.txt \
              --rrna /input_dir/corona_analysis/annotations/human/rRNA_ensembl.txt \
              -i /input_dir/corona_analysis/annotations/human/salmon_ann/salmon_hg38_index \
              -p 3 --dumpFeature \
              -o /input_dir/corona_analysis/alignment_out/kidney_scRNA_control/salmon_out_mo_s1 \
              --tgMap /input_dir/corona_analysis/annotations/human/salmon_grch38_gencode_tran2gene.txt
